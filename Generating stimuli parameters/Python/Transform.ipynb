# %%
import pandas as pd

# %%
ref_train = pd.read_csv("Training_Trails_Adult_Lang_Study.csv")
ref_test = pd.read_csv("Testing_Trials_Adult_Lang_Study.csv")

train = pd.read_csv("./Train/train_v3.csv")
test = pd.read_csv("./Test/test_v3.csv")

# %%
train
# Out:
#     trial    item1      item2    item3 casemarker1 casemarker2 casemarker3  \
# 0       1   rakken     dingep   pakrid      chelad     limeber      jeelow
# 1       2   rakken     makkot   pakrid      chelad     limeber      jeelow
# 2       3   barget     dingep  sumbark      chelad     limeber      jeelow
# 3       4   bimdah     haagle   pakrid      chelad     limeber      jeelow
# 4       5  fisslin  goorshell   haagle      chelad     limeber      jeelow
# ..    ...      ...        ...      ...         ...         ...         ...
# 75     16   pakrid     haagle   bimdah     limeber      chelad      jeelow
# 76     17   barget  goorshell   makkot     limeber      chelad      jeelow
# 77     18   barget    fisslin   makkot     limeber      chelad      jeelow
# 78     19   rakken     pakrid   haagle      chelad     limeber      jeelow
# 79     20  sumbark     haagle   rakken      chelad     limeber      jeelow
#
#                                              final       condition  \
# 0       rakken chelad dingep limeber pakrid jeelow      correlated
# 1       rakken chelad makkot limeber pakrid jeelow      correlated
# 2      barget chelad dingep limeber sumbark jeelow      correlated
# 3       bimdah chelad haagle limeber pakrid jeelow      correlated
# 4   fisslin chelad goorshell limeber haagle jeelow      correlated
# ..                                             ...             ...
# 75      pakrid limeber haagle chelad bimdah jeelow  isolated-right
# 76   barget limeber goorshell chelad makkot jeelow  isolated-right
# 77     barget limeber fisslin chelad makkot jeelow  isolated-right
# 78      rakken chelad pakrid limeber haagle jeelow  isolated-right
# 79     sumbark chelad haagle limeber rakken jeelow  isolated-right
#
#                                        audio_sequence  \
# 0   ['rakken.wav', 'chelad.wav', 'dingep.wav', 'li...
# 1   ['rakken.wav', 'chelad.wav', 'makkot.wav', 'li...
# 2   ['barget.wav', 'chelad.wav', 'dingep.wav', 'li...
# 3   ['bimdah.wav', 'chelad.wav', 'haagle.wav', 'li...
# 4   ['fisslin.wav', 'chelad.wav', 'goorshell.wav',...
# ..                                                ...
# 75  ['pakrid.wav', 'limeber.wav', 'haagle.wav', 'c...
# 76  ['barget.wav', 'limeber.wav', 'goorshell.wav',...
# 77  ['barget.wav', 'limeber.wav', 'fisslin.wav', '...
# 78  ['rakken.wav', 'chelad.wav', 'pakrid.wav', 'li...
# 79  ['sumbark.wav', 'chelad.wav', 'haagle.wav', 'l...
#
#                                        image_sequence
# 0    ['Picture2.png', 'Picture6.png', 'Picture3.png']
# 1    ['Picture2.png', 'Picture4.png', 'Picture3.png']
# 2    ['Picture8.png', 'Picture6.png', 'Picture7.png']
# 3   ['Picture10.png', 'Picture1.png', 'Picture3.png']
# 4    ['Picture9.png', 'Picture5.png', 'Picture1.png']
# ..                                                ...
# 75  ['Picture3.png', 'Picture1.png', 'Picture10.png']
# 76   ['Picture8.png', 'Picture5.png', 'Picture4.png']
# 77   ['Picture8.png', 'Picture9.png', 'Picture4.png']
# 78   ['Picture2.png', 'Picture3.png', 'Picture1.png']
# 79   ['Picture7.png', 'Picture1.png', 'Picture2.png']
#
# [80 rows x 11 columns]

# %%
test
# Out:
#     trial      item1      item2      item3 casemarker1 casemarker2  \
# 0       5    sumbark     haagle     makkot     limeber      jeelow
# 1      12     pakrid     rakken     haagle     limeber      jeelow
# 2      31     rakken  goorshell     haagle     limeber      jeelow
# 3      38     makkot     pakrid     dingep     limeber      jeelow
# 4      35    sumbark  goorshell     makkot     limeber      jeelow
# 5      47     bimdah    fisslin  goorshell     limeber      jeelow
# 6       1     haagle  goorshell    fisslin     limeber      jeelow
# 7      30  goorshell     haagle    sumbark     limeber      jeelow
# 8      22    sumbark     haagle     dingep     limeber      jeelow
# 9      37    fisslin     pakrid  goorshell     limeber      jeelow
# 10     42    sumbark     barget     makkot     limeber      jeelow
# 11     15    sumbark     dingep     barget     limeber      jeelow
# 12     46     makkot    sumbark     rakken     limeber      jeelow
# 13     20     makkot     dingep     barget     limeber      chelad
# 14     36     haagle     barget    fisslin     limeber      jeelow
# 15     42    sumbark     barget     makkot     limeber      chelad
# 16     45     haagle  goorshell     barget     limeber      chelad
# 17     16     haagle     bimdah     dingep     limeber      jeelow
# 18     12     pakrid     rakken     haagle     limeber      chelad
# 19     48     barget     pakrid     dingep     limeber      chelad
# 20      1     haagle  goorshell    fisslin     limeber      chelad
# 21     32     dingep     makkot     bimdah     limeber      jeelow
# 22      5    sumbark     haagle     makkot     limeber      jeelow
# 23     10     haagle     makkot     bimdah     limeber      chelad
# 24     37    fisslin     pakrid  goorshell      chelad      jeelow
# 25     44     haagle     rakken     bimdah     limeber      jeelow
# 26     28    sumbark     bimdah     makkot      chelad      jeelow
# 27     38     makkot     pakrid     dingep     limeber      jeelow
# 28     32     dingep     makkot     bimdah     limeber      jeelow
# 29      6    sumbark     rakken    fisslin     limeber      jeelow
# 30     45     haagle  goorshell     barget     limeber      jeelow
# 31     48     barget     pakrid     dingep     limeber      jeelow
# 32     18     pakrid     rakken     bimdah      chelad      jeelow
# 33     41     bimdah     rakken     barget      chelad      jeelow
# 34     23     rakken  goorshell     makkot     limeber      jeelow
# 35     22    sumbark     haagle     dingep      chelad      jeelow
# 36      6    sumbark     rakken    fisslin      jeelow     limeber
# 37     31     rakken  goorshell     haagle      jeelow     limeber
# 38      2     pakrid    sumbark     bimdah      jeelow     limeber
# 39     40     makkot     barget    fisslin      jeelow     limeber
# 40      5    sumbark     haagle     makkot     limeber      jeelow
# 41     16     haagle     bimdah     dingep      jeelow     limeber
# 42     17     makkot     dingep  goorshell      jeelow     limeber
# 43     39     makkot     bimdah     dingep     limeber      jeelow
# 44     18     pakrid     rakken     bimdah      jeelow     limeber
# 45     21  goorshell     makkot    fisslin      jeelow     limeber
# 46     26     makkot  goorshell     dingep      jeelow     limeber
# 47      7     rakken  goorshell     bimdah     limeber      jeelow
#
#    casemarker3                                           final  \
# 0       chelad     sumbark limeber haagle jeelow makkot chelad
# 1       chelad      pakrid limeber rakken jeelow haagle chelad
# 2       chelad   rakken limeber goorshell jeelow haagle chelad
# 3       chelad      makkot limeber pakrid jeelow dingep chelad
# 4       chelad  sumbark limeber goorshell jeelow makkot chelad
# 5       chelad  bimdah limeber fisslin jeelow goorshell chelad
# 6       chelad  haagle limeber goorshell jeelow fisslin chelad
# 7       chelad  goorshell limeber haagle jeelow sumbark chelad
# 8       chelad     sumbark limeber haagle jeelow dingep chelad
# 9       chelad  fisslin limeber pakrid jeelow goorshell chelad
# 10      chelad     sumbark limeber barget jeelow makkot chelad
# 11      chelad     sumbark limeber dingep jeelow barget chelad
# 12      chelad     makkot limeber sumbark jeelow rakken chelad
# 13      jeelow      makkot limeber dingep chelad barget jeelow
# 14      chelad     haagle limeber barget jeelow fisslin chelad
# 15      jeelow     sumbark limeber barget chelad makkot jeelow
# 16      jeelow   haagle limeber goorshell chelad barget jeelow
# 17      chelad      haagle limeber bimdah jeelow dingep chelad
# 18      jeelow      pakrid limeber rakken chelad haagle jeelow
# 19      jeelow      barget limeber pakrid chelad dingep jeelow
# 20      jeelow  haagle limeber goorshell chelad fisslin jeelow
# 21      chelad      dingep limeber makkot jeelow bimdah chelad
# 22      chelad     sumbark limeber haagle jeelow makkot chelad
# 23      jeelow      haagle limeber makkot chelad bimdah jeelow
# 24     limeber  fisslin chelad pakrid jeelow goorshell limeber
# 25      chelad      haagle limeber rakken jeelow bimdah chelad
# 26     limeber     sumbark chelad bimdah jeelow makkot limeber
# 27      chelad      makkot limeber pakrid jeelow dingep chelad
# 28      chelad      dingep limeber makkot jeelow bimdah chelad
# 29      chelad    sumbark limeber rakken jeelow fisslin chelad
# 30      chelad   haagle limeber goorshell jeelow barget chelad
# 31      chelad      barget limeber pakrid jeelow dingep chelad
# 32     limeber      pakrid chelad rakken jeelow bimdah limeber
# 33     limeber      bimdah chelad rakken jeelow barget limeber
# 34      chelad   rakken limeber goorshell jeelow makkot chelad
# 35     limeber     sumbark chelad haagle jeelow dingep limeber
# 36      chelad    sumbark jeelow rakken limeber fisslin chelad
# 37      chelad   rakken jeelow goorshell limeber haagle chelad
# 38      chelad     pakrid jeelow sumbark limeber bimdah chelad
# 39      chelad     makkot jeelow barget limeber fisslin chelad
# 40      chelad     sumbark limeber haagle jeelow makkot chelad
# 41      chelad      haagle jeelow bimdah limeber dingep chelad
# 42      chelad   makkot jeelow dingep limeber goorshell chelad
# 43      chelad      makkot limeber bimdah jeelow dingep chelad
# 44      chelad      pakrid jeelow rakken limeber bimdah chelad
# 45      chelad  goorshell jeelow makkot limeber fisslin chelad
# 46      chelad   makkot jeelow goorshell limeber dingep chelad
# 47      chelad   rakken limeber goorshell jeelow bimdah chelad
#
#           condition  foil_category                                foil  \
# 0        correlated  transposition     ['haagle', 'sumbark', 'makkot']
# 1        correlated  transposition      ['haagle', 'rakken', 'pakrid']
# 2        correlated  transposition   ['goorshell', 'rakken', 'haagle']
# 3        correlated  transposition      ['dingep', 'makkot', 'pakrid']
# 4        correlated  transposition  ['makkot', 'sumbark', 'goorshell']
# 5        correlated  transposition  ['goorshell', 'bimdah', 'fisslin']
# 6        correlated     itemchange     ['haagle', 'dingep', 'fisslin']
# 7        correlated     itemchange   ['goorshell', 'haagle', 'dingep']
# 8        correlated     itemchange    ['sumbark', 'fisslin', 'dingep']
# 9        correlated     itemchange  ['fisslin', 'barget', 'goorshell']
# 10       correlated     itemchange  ['sumbark', 'goorshell', 'makkot']
# 11       correlated     itemchange      ['pakrid', 'dingep', 'barget']
# 12    isolated-left  transposition     ['makkot', 'rakken', 'sumbark']
# 13    isolated-left  transposition      ['dingep', 'barget', 'makkot']
# 14    isolated-left  transposition     ['fisslin', 'barget', 'haagle']
# 15    isolated-left  transposition     ['makkot', 'sumbark', 'barget']
# 16    isolated-left  transposition   ['goorshell', 'barget', 'haagle']
# 17    isolated-left  transposition      ['dingep', 'haagle', 'bimdah']
# 18    isolated-left     itemchange     ['fisslin', 'rakken', 'haagle']
# 19    isolated-left     itemchange     ['sumbark', 'pakrid', 'dingep']
# 20    isolated-left     itemchange     ['haagle', 'makkot', 'fisslin']
# 21    isolated-left     itemchange      ['dingep', 'makkot', 'barget']
# 22    isolated-left     itemchange      ['pakrid', 'haagle', 'makkot']
# 23    isolated-left     itemchange     ['haagle', 'makkot', 'fisslin']
# 24  isolated-center  transposition  ['pakrid', 'fisslin', 'goorshell']
# 25  isolated-center  transposition      ['bimdah', 'rakken', 'haagle']
# 26  isolated-center  transposition     ['bimdah', 'sumbark', 'makkot']
# 27  isolated-center  transposition      ['dingep', 'pakrid', 'makkot']
# 28  isolated-center  transposition      ['dingep', 'bimdah', 'makkot']
# 29  isolated-center  transposition    ['fisslin', 'rakken', 'sumbark']
# 30  isolated-center     itemchange      ['haagle', 'bimdah', 'barget']
# 31  isolated-center     itemchange      ['barget', 'rakken', 'dingep']
# 32  isolated-center     itemchange   ['pakrid', 'goorshell', 'bimdah']
# 33  isolated-center     itemchange      ['bimdah', 'rakken', 'makkot']
# 34  isolated-center     itemchange   ['barget', 'goorshell', 'makkot']
# 35  isolated-center     itemchange      ['barget', 'haagle', 'dingep']
# 36   isolated-right  transposition    ['fisslin', 'rakken', 'sumbark']
# 37   isolated-right  transposition   ['haagle', 'rakken', 'goorshell']
# 38   isolated-right  transposition     ['sumbark', 'bimdah', 'pakrid']
# 39   isolated-right  transposition     ['fisslin', 'barget', 'makkot']
# 40   isolated-right  transposition     ['sumbark', 'makkot', 'haagle']
# 41   isolated-right  transposition      ['haagle', 'dingep', 'bimdah']
# 42   isolated-right     itemchange  ['makkot', 'sumbark', 'goorshell']
# 43   isolated-right     itemchange      ['pakrid', 'bimdah', 'dingep']
# 44   isolated-right     itemchange     ['pakrid', 'rakken', 'sumbark']
# 45   isolated-right     itemchange   ['goorshell', 'makkot', 'haagle']
# 46   isolated-right     itemchange   ['barget', 'goorshell', 'dingep']
# 47   isolated-right     itemchange      ['rakken', 'haagle', 'bimdah']
#
#                                 target_audio_sequence  \
# 0   ['sumbark.wav', 'limeber.wav', 'haagle.wav', '...
# 1   ['pakrid.wav', 'limeber.wav', 'rakken.wav', 'j...
# 2   ['rakken.wav', 'limeber.wav', 'goorshell.wav',...
# 3   ['makkot.wav', 'limeber.wav', 'pakrid.wav', 'j...
# 4   ['sumbark.wav', 'limeber.wav', 'goorshell.wav'...
# 5   ['bimdah.wav', 'limeber.wav', 'fisslin.wav', '...
# 6   ['haagle.wav', 'limeber.wav', 'goorshell.wav',...
# 7   ['goorshell.wav', 'limeber.wav', 'haagle.wav',...
# 8   ['sumbark.wav', 'limeber.wav', 'haagle.wav', '...
# 9   ['fisslin.wav', 'limeber.wav', 'pakrid.wav', '...
# 10  ['sumbark.wav', 'limeber.wav', 'barget.wav', '...
# 11  ['sumbark.wav', 'limeber.wav', 'dingep.wav', '...
# 12  ['makkot.wav', 'limeber.wav', 'sumbark.wav', '...
# 13  ['makkot.wav', 'limeber.wav', 'dingep.wav', 'c...
# 14  ['haagle.wav', 'limeber.wav', 'barget.wav', 'j...
# 15  ['sumbark.wav', 'limeber.wav', 'barget.wav', '...
# 16  ['haagle.wav', 'limeber.wav', 'goorshell.wav',...
# 17  ['haagle.wav', 'limeber.wav', 'bimdah.wav', 'j...
# 18  ['pakrid.wav', 'limeber.wav', 'rakken.wav', 'c...
# 19  ['barget.wav', 'limeber.wav', 'pakrid.wav', 'c...
# 20  ['haagle.wav', 'limeber.wav', 'goorshell.wav',...
# 21  ['dingep.wav', 'limeber.wav', 'makkot.wav', 'j...
# 22  ['sumbark.wav', 'limeber.wav', 'haagle.wav', '...
# 23  ['haagle.wav', 'limeber.wav', 'makkot.wav', 'c...
# 24  ['fisslin.wav', 'chelad.wav', 'pakrid.wav', 'j...
# 25  ['haagle.wav', 'limeber.wav', 'rakken.wav', 'j...
# 26  ['sumbark.wav', 'chelad.wav', 'bimdah.wav', 'j...
# 27  ['makkot.wav', 'limeber.wav', 'pakrid.wav', 'j...
# 28  ['dingep.wav', 'limeber.wav', 'makkot.wav', 'j...
# 29  ['sumbark.wav', 'limeber.wav', 'rakken.wav', '...
# 30  ['haagle.wav', 'limeber.wav', 'goorshell.wav',...
# 31  ['barget.wav', 'limeber.wav', 'pakrid.wav', 'j...
# 32  ['pakrid.wav', 'chelad.wav', 'rakken.wav', 'je...
# 33  ['bimdah.wav', 'chelad.wav', 'rakken.wav', 'je...
# 34  ['rakken.wav', 'limeber.wav', 'goorshell.wav',...
# 35  ['sumbark.wav', 'chelad.wav', 'haagle.wav', 'j...
# 36  ['sumbark.wav', 'jeelow.wav', 'rakken.wav', 'l...
# 37  ['rakken.wav', 'jeelow.wav', 'goorshell.wav', ...
# 38  ['pakrid.wav', 'jeelow.wav', 'sumbark.wav', 'l...
# 39  ['makkot.wav', 'jeelow.wav', 'barget.wav', 'li...
# 40  ['sumbark.wav', 'limeber.wav', 'haagle.wav', '...
# 41  ['haagle.wav', 'jeelow.wav', 'bimdah.wav', 'li...
# 42  ['makkot.wav', 'jeelow.wav', 'dingep.wav', 'li...
# 43  ['makkot.wav', 'limeber.wav', 'bimdah.wav', 'j...
# 44  ['pakrid.wav', 'jeelow.wav', 'rakken.wav', 'li...
# 45  ['goorshell.wav', 'jeelow.wav', 'makkot.wav', ...
# 46  ['makkot.wav', 'jeelow.wav', 'goorshell.wav', ...
# 47  ['rakken.wav', 'limeber.wav', 'goorshell.wav',...
#
#                                foil_audio_sequence  \
# 0      ['haagle.wav', 'sumbark.wav', 'makkot.wav']
# 1       ['haagle.wav', 'rakken.wav', 'pakrid.wav']
# 2    ['goorshell.wav', 'rakken.wav', 'haagle.wav']
# 3       ['dingep.wav', 'makkot.wav', 'pakrid.wav']
# 4   ['makkot.wav', 'sumbark.wav', 'goorshell.wav']
# 5   ['goorshell.wav', 'bimdah.wav', 'fisslin.wav']
# 6      ['haagle.wav', 'dingep.wav', 'fisslin.wav']
# 7    ['goorshell.wav', 'haagle.wav', 'dingep.wav']
# 8     ['sumbark.wav', 'fisslin.wav', 'dingep.wav']
# 9   ['fisslin.wav', 'barget.wav', 'goorshell.wav']
# 10  ['sumbark.wav', 'goorshell.wav', 'makkot.wav']
# 11      ['pakrid.wav', 'dingep.wav', 'barget.wav']
# 12     ['makkot.wav', 'rakken.wav', 'sumbark.wav']
# 13      ['dingep.wav', 'barget.wav', 'makkot.wav']
# 14     ['fisslin.wav', 'barget.wav', 'haagle.wav']
# 15     ['makkot.wav', 'sumbark.wav', 'barget.wav']
# 16   ['goorshell.wav', 'barget.wav', 'haagle.wav']
# 17      ['dingep.wav', 'haagle.wav', 'bimdah.wav']
# 18     ['fisslin.wav', 'rakken.wav', 'haagle.wav']
# 19     ['sumbark.wav', 'pakrid.wav', 'dingep.wav']
# 20     ['haagle.wav', 'makkot.wav', 'fisslin.wav']
# 21      ['dingep.wav', 'makkot.wav', 'barget.wav']
# 22      ['pakrid.wav', 'haagle.wav', 'makkot.wav']
# 23     ['haagle.wav', 'makkot.wav', 'fisslin.wav']
# 24  ['pakrid.wav', 'fisslin.wav', 'goorshell.wav']
# 25      ['bimdah.wav', 'rakken.wav', 'haagle.wav']
# 26     ['bimdah.wav', 'sumbark.wav', 'makkot.wav']
# 27      ['dingep.wav', 'pakrid.wav', 'makkot.wav']
# 28      ['dingep.wav', 'bimdah.wav', 'makkot.wav']
# 29    ['fisslin.wav', 'rakken.wav', 'sumbark.wav']
# 30      ['haagle.wav', 'bimdah.wav', 'barget.wav']
# 31      ['barget.wav', 'rakken.wav', 'dingep.wav']
# 32   ['pakrid.wav', 'goorshell.wav', 'bimdah.wav']
# 33      ['bimdah.wav', 'rakken.wav', 'makkot.wav']
# 34   ['barget.wav', 'goorshell.wav', 'makkot.wav']
# 35      ['barget.wav', 'haagle.wav', 'dingep.wav']
# 36    ['fisslin.wav', 'rakken.wav', 'sumbark.wav']
# 37   ['haagle.wav', 'rakken.wav', 'goorshell.wav']
# 38     ['sumbark.wav', 'bimdah.wav', 'pakrid.wav']
# 39     ['fisslin.wav', 'barget.wav', 'makkot.wav']
# 40     ['sumbark.wav', 'makkot.wav', 'haagle.wav']
# 41      ['haagle.wav', 'dingep.wav', 'bimdah.wav']
# 42  ['makkot.wav', 'sumbark.wav', 'goorshell.wav']
# 43      ['pakrid.wav', 'bimdah.wav', 'dingep.wav']
# 44     ['pakrid.wav', 'rakken.wav', 'sumbark.wav']
# 45   ['goorshell.wav', 'makkot.wav', 'haagle.wav']
# 46   ['barget.wav', 'goorshell.wav', 'dingep.wav']
# 47      ['rakken.wav', 'haagle.wav', 'bimdah.wav']
#
#                                 target_image_sequence  \
# 0    ['Picture7.png', 'Picture1.png', 'Picture4.png']
# 1    ['Picture3.png', 'Picture2.png', 'Picture1.png']
# 2    ['Picture2.png', 'Picture5.png', 'Picture1.png']
# 3    ['Picture4.png', 'Picture3.png', 'Picture6.png']
# 4    ['Picture7.png', 'Picture5.png', 'Picture4.png']
# 5   ['Picture10.png', 'Picture9.png', 'Picture5.png']
# 6    ['Picture1.png', 'Picture5.png', 'Picture9.png']
# 7    ['Picture5.png', 'Picture1.png', 'Picture7.png']
# 8    ['Picture7.png', 'Picture1.png', 'Picture6.png']
# 9    ['Picture9.png', 'Picture3.png', 'Picture5.png']
# 10   ['Picture7.png', 'Picture8.png', 'Picture4.png']
# 11   ['Picture7.png', 'Picture6.png', 'Picture8.png']
# 12   ['Picture4.png', 'Picture7.png', 'Picture2.png']
# 13   ['Picture4.png', 'Picture6.png', 'Picture8.png']
# 14   ['Picture1.png', 'Picture8.png', 'Picture9.png']
# 15   ['Picture7.png', 'Picture8.png', 'Picture4.png']
# 16   ['Picture1.png', 'Picture5.png', 'Picture8.png']
# 17  ['Picture1.png', 'Picture10.png', 'Picture6.png']
# 18   ['Picture3.png', 'Picture2.png', 'Picture1.png']
# 19   ['Picture8.png', 'Picture3.png', 'Picture6.png']
# 20   ['Picture1.png', 'Picture5.png', 'Picture9.png']
# 21  ['Picture6.png', 'Picture4.png', 'Picture10.png']
# 22   ['Picture7.png', 'Picture1.png', 'Picture4.png']
# 23  ['Picture1.png', 'Picture4.png', 'Picture10.png']
# 24   ['Picture9.png', 'Picture3.png', 'Picture5.png']
# 25  ['Picture1.png', 'Picture2.png', 'Picture10.png']
# 26  ['Picture7.png', 'Picture10.png', 'Picture4.png']
# 27   ['Picture4.png', 'Picture3.png', 'Picture6.png']
# 28  ['Picture6.png', 'Picture4.png', 'Picture10.png']
# 29   ['Picture7.png', 'Picture2.png', 'Picture9.png']
# 30   ['Picture1.png', 'Picture5.png', 'Picture8.png']
# 31   ['Picture8.png', 'Picture3.png', 'Picture6.png']
# 32  ['Picture3.png', 'Picture2.png', 'Picture10.png']
# 33  ['Picture10.png', 'Picture2.png', 'Picture8.png']
# 34   ['Picture2.png', 'Picture5.png', 'Picture4.png']
# 35   ['Picture7.png', 'Picture1.png', 'Picture6.png']
# 36   ['Picture7.png', 'Picture2.png', 'Picture9.png']
# 37   ['Picture2.png', 'Picture5.png', 'Picture1.png']
# 38  ['Picture3.png', 'Picture7.png', 'Picture10.png']
# 39   ['Picture4.png', 'Picture8.png', 'Picture9.png']
# 40   ['Picture7.png', 'Picture1.png', 'Picture4.png']
# 41  ['Picture1.png', 'Picture10.png', 'Picture6.png']
# 42   ['Picture4.png', 'Picture6.png', 'Picture5.png']
# 43  ['Picture4.png', 'Picture10.png', 'Picture6.png']
# 44  ['Picture3.png', 'Picture2.png', 'Picture10.png']
# 45   ['Picture5.png', 'Picture4.png', 'Picture9.png']
# 46   ['Picture4.png', 'Picture5.png', 'Picture6.png']
# 47  ['Picture2.png', 'Picture5.png', 'Picture10.png']
#
#                                   foil_image_sequence
# 0    ['Picture1.png', 'Picture7.png', 'Picture4.png']
# 1    ['Picture1.png', 'Picture2.png', 'Picture3.png']
# 2    ['Picture5.png', 'Picture2.png', 'Picture1.png']
# 3    ['Picture6.png', 'Picture4.png', 'Picture3.png']
# 4    ['Picture4.png', 'Picture7.png', 'Picture5.png']
# 5   ['Picture5.png', 'Picture10.png', 'Picture9.png']
# 6    ['Picture1.png', 'Picture6.png', 'Picture9.png']
# 7    ['Picture5.png', 'Picture1.png', 'Picture6.png']
# 8    ['Picture7.png', 'Picture9.png', 'Picture6.png']
# 9    ['Picture9.png', 'Picture8.png', 'Picture5.png']
# 10   ['Picture7.png', 'Picture5.png', 'Picture4.png']
# 11   ['Picture3.png', 'Picture6.png', 'Picture8.png']
# 12   ['Picture4.png', 'Picture2.png', 'Picture7.png']
# 13   ['Picture6.png', 'Picture8.png', 'Picture4.png']
# 14   ['Picture9.png', 'Picture8.png', 'Picture1.png']
# 15   ['Picture4.png', 'Picture7.png', 'Picture8.png']
# 16   ['Picture5.png', 'Picture8.png', 'Picture1.png']
# 17  ['Picture6.png', 'Picture1.png', 'Picture10.png']
# 18   ['Picture9.png', 'Picture2.png', 'Picture1.png']
# 19   ['Picture7.png', 'Picture3.png', 'Picture6.png']
# 20   ['Picture1.png', 'Picture4.png', 'Picture9.png']
# 21   ['Picture6.png', 'Picture4.png', 'Picture8.png']
# 22   ['Picture3.png', 'Picture1.png', 'Picture4.png']
# 23   ['Picture1.png', 'Picture4.png', 'Picture9.png']
# 24   ['Picture3.png', 'Picture9.png', 'Picture5.png']
# 25  ['Picture10.png', 'Picture2.png', 'Picture1.png']
# 26  ['Picture10.png', 'Picture7.png', 'Picture4.png']
# 27   ['Picture6.png', 'Picture3.png', 'Picture4.png']
# 28  ['Picture6.png', 'Picture10.png', 'Picture4.png']
# 29   ['Picture9.png', 'Picture2.png', 'Picture7.png']
# 30  ['Picture1.png', 'Picture10.png', 'Picture8.png']
# 31   ['Picture8.png', 'Picture2.png', 'Picture6.png']
# 32  ['Picture3.png', 'Picture5.png', 'Picture10.png']
# 33  ['Picture10.png', 'Picture2.png', 'Picture4.png']
# 34   ['Picture8.png', 'Picture5.png', 'Picture4.png']
# 35   ['Picture8.png', 'Picture1.png', 'Picture6.png']
# 36   ['Picture9.png', 'Picture2.png', 'Picture7.png']
# 37   ['Picture1.png', 'Picture2.png', 'Picture5.png']
# 38  ['Picture7.png', 'Picture10.png', 'Picture3.png']
# 39   ['Picture9.png', 'Picture8.png', 'Picture4.png']
# 40   ['Picture7.png', 'Picture4.png', 'Picture1.png']
# 41  ['Picture1.png', 'Picture6.png', 'Picture10.png']
# 42   ['Picture4.png', 'Picture7.png', 'Picture5.png']
# 43  ['Picture3.png', 'Picture10.png', 'Picture6.png']
# 44   ['Picture3.png', 'Picture2.png', 'Picture7.png']
# 45   ['Picture5.png', 'Picture4.png', 'Picture1.png']
# 46   ['Picture8.png', 'Picture5.png', 'Picture6.png']
# 47  ['Picture2.png', 'Picture1.png', 'Picture10.png']

# %% [markdown]
# ### train-transformation

# %%
ref_train
# Out:
#    number            english name                chinese name     Condition 1  \
# 0      11                  eleven                     ten one        ti bo ti
# 1      12                  twelve                     ten two        ti bo bi
# 2     121  one hundred twenty one  one hundreded two ten one   ti zu bi bo ti
# 3     122  one hundred twenty two     one hundred two ten two  ti zu bi bo bi
#
#       Condition 2                                    Visual
# 0        ti bo ti                Picture1.png, Picture1.png
# 1        ti bo bi                Picture1.png, Picture2.png
# 2  ti zu bi bo ti  Picture1.png, Picture2.png, Picture1.png
# 3  ti zu bi bo bi  Picture1.png, Picture2.png, Picture2.png

# %%
train.head(4)
# Out:
#    trial   item1   item2    item3 casemarker1 casemarker2 casemarker3  \
# 0      1  rakken  dingep   pakrid      nellby     limeber      chelad
# 1      2  rakken  makkot   pakrid      nellby     limeber      chelad
# 2      3  barget  dingep  sumbark      nellby     limeber      chelad
# 3      4  bimdah  haagle   pakrid      nellby     limeber      chelad
#
#                                          final   condition  \
# 0   rakken nellby dingep limeber pakrid chelad  correlated
# 1   rakken nellby makkot limeber pakrid chelad  correlated
# 2  barget nellby dingep limeber sumbark chelad  correlated
# 3   bimdah nellby haagle limeber pakrid chelad  correlated
#
#                                       audio_sequence
# 0  ['rakken.wav', 'nellby.wav', 'dingep.wav', 'li...
# 1  ['rakken.wav', 'nellby.wav', 'makkot.wav', 'li...
# 2  ['barget.wav', 'nellby.wav', 'dingep.wav', 'li...
# 3  ['bimdah.wav', 'nellby.wav', 'haagle.wav', 'li...

# %%
train_dfs = {}
for condition in train['condition'].unique():
        print(f"- {condition}")
        train_dfs[condition] = train[train['condition']==condition]
        
train_dfs
# Out:
# - correlated
# - isolated-left
# - isolated-center
# - isolated-right
# {'correlated':     trial      item1      item2      item3 casemarker1 casemarker2  \
#  0       1     rakken     dingep     pakrid      chelad     limeber
#  1       2     rakken     makkot     pakrid      chelad     limeber
#  2       3     barget     dingep    sumbark      chelad     limeber
#  3       4     bimdah     haagle     pakrid      chelad     limeber
#  4       5    fisslin  goorshell     haagle      chelad     limeber
#  5       6     rakken     makkot    fisslin      chelad     limeber
#  6       7     dingep  goorshell    sumbark      chelad     limeber
#  7       8     rakken     dingep    sumbark      chelad     limeber
#  8       9  goorshell     makkot    sumbark      chelad     limeber
#  9      10     haagle     pakrid     rakken      chelad     limeber
#  10     11     bimdah     haagle  goorshell      chelad     limeber
#  11     12     barget    fisslin     haagle      chelad     limeber
#  12     13    sumbark    fisslin     makkot      chelad     limeber
#  13     14    fisslin     haagle     bimdah      chelad     limeber
#  14     15     makkot     rakken     haagle      chelad     limeber
#  15     16     pakrid     haagle     bimdah      chelad     limeber
#  16     17     barget  goorshell     makkot      chelad     limeber
#  17     18     barget    fisslin     makkot      chelad     limeber
#  18     19     rakken     pakrid     haagle      chelad     limeber
#  19     20    sumbark     haagle     rakken      chelad     limeber
#
#     casemarker3                                           final   condition  \
#  0       jeelow      rakken chelad dingep limeber pakrid jeelow  correlated
#  1       jeelow      rakken chelad makkot limeber pakrid jeelow  correlated
#  2       jeelow     barget chelad dingep limeber sumbark jeelow  correlated
#  3       jeelow      bimdah chelad haagle limeber pakrid jeelow  correlated
#  4       jeelow  fisslin chelad goorshell limeber haagle jeelow  correlated
#  5       jeelow     rakken chelad makkot limeber fisslin jeelow  correlated
#  6       jeelow  dingep chelad goorshell limeber sumbark jeelow  correlated
#  7       jeelow     rakken chelad dingep limeber sumbark jeelow  correlated
#  8       jeelow  goorshell chelad makkot limeber sumbark jeelow  correlated
#  9       jeelow      haagle chelad pakrid limeber rakken jeelow  correlated
#  10      jeelow   bimdah chelad haagle limeber goorshell jeelow  correlated
#  11      jeelow     barget chelad fisslin limeber haagle jeelow  correlated
#  12      jeelow    sumbark chelad fisslin limeber makkot jeelow  correlated
#  13      jeelow     fisslin chelad haagle limeber bimdah jeelow  correlated
#  14      jeelow      makkot chelad rakken limeber haagle jeelow  correlated
#  15      jeelow      pakrid chelad haagle limeber bimdah jeelow  correlated
#  16      jeelow   barget chelad goorshell limeber makkot jeelow  correlated
#  17      jeelow     barget chelad fisslin limeber makkot jeelow  correlated
#  18      jeelow      rakken chelad pakrid limeber haagle jeelow  correlated
#  19      jeelow     sumbark chelad haagle limeber rakken jeelow  correlated
#
#                                         audio_sequence  \
#  0   ['rakken.wav', 'chelad.wav', 'dingep.wav', 'li...
#  1   ['rakken.wav', 'chelad.wav', 'makkot.wav', 'li...
#  2   ['barget.wav', 'chelad.wav', 'dingep.wav', 'li...
#  3   ['bimdah.wav', 'chelad.wav', 'haagle.wav', 'li...
#  4   ['fisslin.wav', 'chelad.wav', 'goorshell.wav',...
#  5   ['rakken.wav', 'chelad.wav', 'makkot.wav', 'li...
#  6   ['dingep.wav', 'chelad.wav', 'goorshell.wav', ...
#  7   ['rakken.wav', 'chelad.wav', 'dingep.wav', 'li...
#  8   ['goorshell.wav', 'chelad.wav', 'makkot.wav', ...
#  9   ['haagle.wav', 'chelad.wav', 'pakrid.wav', 'li...
#  10  ['bimdah.wav', 'chelad.wav', 'haagle.wav', 'li...
#  11  ['barget.wav', 'chelad.wav', 'fisslin.wav', 'l...
#  12  ['sumbark.wav', 'chelad.wav', 'fisslin.wav', '...
#  13  ['fisslin.wav', 'chelad.wav', 'haagle.wav', 'l...
#  14  ['makkot.wav', 'chelad.wav', 'rakken.wav', 'li...
#  15  ['pakrid.wav', 'chelad.wav', 'haagle.wav', 'li...
#  16  ['barget.wav', 'chelad.wav', 'goorshell.wav', ...
#  17  ['barget.wav', 'chelad.wav', 'fisslin.wav', 'l...
#  18  ['rakken.wav', 'chelad.wav', 'pakrid.wav', 'li...
#  19  ['sumbark.wav', 'chelad.wav', 'haagle.wav', 'l...
#
#                                         image_sequence
#  0    ['Picture2.png', 'Picture6.png', 'Picture3.png']
#  1    ['Picture2.png', 'Picture4.png', 'Picture3.png']
#  2    ['Picture8.png', 'Picture6.png', 'Picture7.png']
#  3   ['Picture10.png', 'Picture1.png', 'Picture3.png']
#  4    ['Picture9.png', 'Picture5.png', 'Picture1.png']
#  5    ['Picture2.png', 'Picture4.png', 'Picture9.png']
#  6    ['Picture6.png', 'Picture5.png', 'Picture7.png']
#  7    ['Picture2.png', 'Picture6.png', 'Picture7.png']
#  8    ['Picture5.png', 'Picture4.png', 'Picture7.png']
#  9    ['Picture1.png', 'Picture3.png', 'Picture2.png']
#  10  ['Picture10.png', 'Picture1.png', 'Picture5.png']
#  11   ['Picture8.png', 'Picture9.png', 'Picture1.png']
#  12   ['Picture7.png', 'Picture9.png', 'Picture4.png']
#  13  ['Picture9.png', 'Picture1.png', 'Picture10.png']
#  14   ['Picture4.png', 'Picture2.png', 'Picture1.png']
#  15  ['Picture3.png', 'Picture1.png', 'Picture10.png']
#  16   ['Picture8.png', 'Picture5.png', 'Picture4.png']
#  17   ['Picture8.png', 'Picture9.png', 'Picture4.png']
#  18   ['Picture2.png', 'Picture3.png', 'Picture1.png']
#  19   ['Picture7.png', 'Picture1.png', 'Picture2.png']  ,
#  'isolated-left':     trial      item1      item2      item3 casemarker1 casemarker2  \
#  20      1     rakken     dingep     pakrid      chelad      jeelow
#  21      2     rakken     makkot     pakrid      chelad     limeber
#  22      3     barget     dingep    sumbark      chelad     limeber
#  23      4     bimdah     haagle     pakrid      chelad     limeber
#  24      5    fisslin  goorshell     haagle      chelad     limeber
#  25      6     rakken     makkot    fisslin      chelad     limeber
#  26      7     dingep  goorshell    sumbark      chelad      jeelow
#  27      8     rakken     dingep    sumbark      chelad     limeber
#  28      9  goorshell     makkot    sumbark      chelad      jeelow
#  29     10     haagle     pakrid     rakken      chelad     limeber
#  30     11     bimdah     haagle  goorshell      chelad      jeelow
#  31     12     barget    fisslin     haagle      chelad     limeber
#  32     13    sumbark    fisslin     makkot      chelad      jeelow
#  33     14    fisslin     haagle     bimdah      chelad     limeber
#  34     15     makkot     rakken     haagle      chelad     limeber
#  35     16     pakrid     haagle     bimdah      chelad      jeelow
#  36     17     barget  goorshell     makkot      chelad      jeelow
#  37     18     barget    fisslin     makkot      chelad      jeelow
#  38     19     rakken     pakrid     haagle      chelad      jeelow
#  39     20    sumbark     haagle     rakken      chelad      jeelow
#
#     casemarker3                                           final      condition  \
#  20     limeber      rakken chelad dingep jeelow pakrid limeber  isolated-left
#  21      jeelow      rakken chelad makkot limeber pakrid jeelow  isolated-left
#  22      jeelow     barget chelad dingep limeber sumbark jeelow  isolated-left
#  23      jeelow      bimdah chelad haagle limeber pakrid jeelow  isolated-left
#  24      jeelow  fisslin chelad goorshell limeber haagle jeelow  isolated-left
#  25      jeelow     rakken chelad makkot limeber fisslin jeelow  isolated-left
#  26     limeber  dingep chelad goorshell jeelow sumbark limeber  isolated-left
#  27      jeelow     rakken chelad dingep limeber sumbark jeelow  isolated-left
#  28     limeber  goorshell chelad makkot jeelow sumbark limeber  isolated-left
#  29      jeelow      haagle chelad pakrid limeber rakken jeelow  isolated-left
#  30     limeber   bimdah chelad haagle jeelow goorshell limeber  isolated-left
#  31      jeelow     barget chelad fisslin limeber haagle jeelow  isolated-left
#  32     limeber    sumbark chelad fisslin jeelow makkot limeber  isolated-left
#  33      jeelow     fisslin chelad haagle limeber bimdah jeelow  isolated-left
#  34      jeelow      makkot chelad rakken limeber haagle jeelow  isolated-left
#  35     limeber      pakrid chelad haagle jeelow bimdah limeber  isolated-left
#  36     limeber   barget chelad goorshell jeelow makkot limeber  isolated-left
#  37     limeber     barget chelad fisslin jeelow makkot limeber  isolated-left
#  38     limeber      rakken chelad pakrid jeelow haagle limeber  isolated-left
#  39     limeber     sumbark chelad haagle jeelow rakken limeber  isolated-left
#
#                                         audio_sequence  \
#  20  ['rakken.wav', 'chelad.wav', 'dingep.wav', 'je...
#  21  ['rakken.wav', 'chelad.wav', 'makkot.wav', 'li...
#  22  ['barget.wav', 'chelad.wav', 'dingep.wav', 'li...
#  23  ['bimdah.wav', 'chelad.wav', 'haagle.wav', 'li...
#  24  ['fisslin.wav', 'chelad.wav', 'goorshell.wav',...
#  25  ['rakken.wav', 'chelad.wav', 'makkot.wav', 'li...
#  26  ['dingep.wav', 'chelad.wav', 'goorshell.wav', ...
#  27  ['rakken.wav', 'chelad.wav', 'dingep.wav', 'li...
#  28  ['goorshell.wav', 'chelad.wav', 'makkot.wav', ...
#  29  ['haagle.wav', 'chelad.wav', 'pakrid.wav', 'li...
#  30  ['bimdah.wav', 'chelad.wav', 'haagle.wav', 'je...
#  31  ['barget.wav', 'chelad.wav', 'fisslin.wav', 'l...
#  32  ['sumbark.wav', 'chelad.wav', 'fisslin.wav', '...
#  33  ['fisslin.wav', 'chelad.wav', 'haagle.wav', 'l...
#  34  ['makkot.wav', 'chelad.wav', 'rakken.wav', 'li...
#  35  ['pakrid.wav', 'chelad.wav', 'haagle.wav', 'je...
#  36  ['barget.wav', 'chelad.wav', 'goorshell.wav', ...
#  37  ['barget.wav', 'chelad.wav', 'fisslin.wav', 'j...
#  38  ['rakken.wav', 'chelad.wav', 'pakrid.wav', 'je...
#  39  ['sumbark.wav', 'chelad.wav', 'haagle.wav', 'j...
#
#                                         image_sequence
#  20   ['Picture2.png', 'Picture6.png', 'Picture3.png']
#  21   ['Picture2.png', 'Picture4.png', 'Picture3.png']
#  22   ['Picture8.png', 'Picture6.png', 'Picture7.png']
#  23  ['Picture10.png', 'Picture1.png', 'Picture3.png']
#  24   ['Picture9.png', 'Picture5.png', 'Picture1.png']
#  25   ['Picture2.png', 'Picture4.png', 'Picture9.png']
#  26   ['Picture6.png', 'Picture5.png', 'Picture7.png']
#  27   ['Picture2.png', 'Picture6.png', 'Picture7.png']
#  28   ['Picture5.png', 'Picture4.png', 'Picture7.png']
#  29   ['Picture1.png', 'Picture3.png', 'Picture2.png']
#  30  ['Picture10.png', 'Picture1.png', 'Picture5.png']
#  31   ['Picture8.png', 'Picture9.png', 'Picture1.png']
#  32   ['Picture7.png', 'Picture9.png', 'Picture4.png']
#  33  ['Picture9.png', 'Picture1.png', 'Picture10.png']
#  34   ['Picture4.png', 'Picture2.png', 'Picture1.png']
#  35  ['Picture3.png', 'Picture1.png', 'Picture10.png']
#  36   ['Picture8.png', 'Picture5.png', 'Picture4.png']
#  37   ['Picture8.png', 'Picture9.png', 'Picture4.png']
#  38   ['Picture2.png', 'Picture3.png', 'Picture1.png']
#  39   ['Picture7.png', 'Picture1.png', 'Picture2.png']  ,
#  'isolated-center':     trial      item1      item2      item3 casemarker1 casemarker2  \
#  40      1     rakken     dingep     pakrid      jeelow     limeber
#  41      2     rakken     makkot     pakrid      chelad     limeber
#  42      3     barget     dingep    sumbark      jeelow     limeber
#  43      4     bimdah     haagle     pakrid      chelad     limeber
#  44      5    fisslin  goorshell     haagle      chelad     limeber
#  45      6     rakken     makkot    fisslin      jeelow     limeber
#  46      7     dingep  goorshell    sumbark      chelad     limeber
#  47      8     rakken     dingep    sumbark      chelad     limeber
#  48      9  goorshell     makkot    sumbark      jeelow     limeber
#  49     10     haagle     pakrid     rakken      chelad     limeber
#  50     11     bimdah     haagle  goorshell      jeelow     limeber
#  51     12     barget    fisslin     haagle      chelad     limeber
#  52     13    sumbark    fisslin     makkot      chelad     limeber
#  53     14    fisslin     haagle     bimdah      jeelow     limeber
#  54     15     makkot     rakken     haagle      chelad     limeber
#  55     16     pakrid     haagle     bimdah      jeelow     limeber
#  56     17     barget  goorshell     makkot      jeelow     limeber
#  57     18     barget    fisslin     makkot      jeelow     limeber
#  58     19     rakken     pakrid     haagle      chelad     limeber
#  59     20    sumbark     haagle     rakken      jeelow     limeber
#
#     casemarker3                                           final  \
#  40      chelad      rakken jeelow dingep limeber pakrid chelad
#  41      jeelow      rakken chelad makkot limeber pakrid jeelow
#  42      chelad     barget jeelow dingep limeber sumbark chelad
#  43      jeelow      bimdah chelad haagle limeber pakrid jeelow
#  44      jeelow  fisslin chelad goorshell limeber haagle jeelow
#  45      chelad     rakken jeelow makkot limeber fisslin chelad
#  46      jeelow  dingep chelad goorshell limeber sumbark jeelow
#  47      jeelow     rakken chelad dingep limeber sumbark jeelow
#  48      chelad  goorshell jeelow makkot limeber sumbark chelad
#  49      jeelow      haagle chelad pakrid limeber rakken jeelow
#  50      chelad   bimdah jeelow haagle limeber goorshell chelad
#  51      jeelow     barget chelad fisslin limeber haagle jeelow
#  52      jeelow    sumbark chelad fisslin limeber makkot jeelow
#  53      chelad     fisslin jeelow haagle limeber bimdah chelad
#  54      jeelow      makkot chelad rakken limeber haagle jeelow
#  55      chelad      pakrid jeelow haagle limeber bimdah chelad
#  56      chelad   barget jeelow goorshell limeber makkot chelad
#  57      chelad     barget jeelow fisslin limeber makkot chelad
#  58      jeelow      rakken chelad pakrid limeber haagle jeelow
#  59      chelad     sumbark jeelow haagle limeber rakken chelad
#
#            condition                                     audio_sequence  \
#  40  isolated-center  ['rakken.wav', 'jeelow.wav', 'dingep.wav', 'li...
#  41  isolated-center  ['rakken.wav', 'chelad.wav', 'makkot.wav', 'li...
#  42  isolated-center  ['barget.wav', 'jeelow.wav', 'dingep.wav', 'li...
#  43  isolated-center  ['bimdah.wav', 'chelad.wav', 'haagle.wav', 'li...
#  44  isolated-center  ['fisslin.wav', 'chelad.wav', 'goorshell.wav',...
#  45  isolated-center  ['rakken.wav', 'jeelow.wav', 'makkot.wav', 'li...
#  46  isolated-center  ['dingep.wav', 'chelad.wav', 'goorshell.wav', ...
#  47  isolated-center  ['rakken.wav', 'chelad.wav', 'dingep.wav', 'li...
#  48  isolated-center  ['goorshell.wav', 'jeelow.wav', 'makkot.wav', ...
#  49  isolated-center  ['haagle.wav', 'chelad.wav', 'pakrid.wav', 'li...
#  50  isolated-center  ['bimdah.wav', 'jeelow.wav', 'haagle.wav', 'li...
#  51  isolated-center  ['barget.wav', 'chelad.wav', 'fisslin.wav', 'l...
#  52  isolated-center  ['sumbark.wav', 'chelad.wav', 'fisslin.wav', '...
#  53  isolated-center  ['fisslin.wav', 'jeelow.wav', 'haagle.wav', 'l...
#  54  isolated-center  ['makkot.wav', 'chelad.wav', 'rakken.wav', 'li...
#  55  isolated-center  ['pakrid.wav', 'jeelow.wav', 'haagle.wav', 'li...
#  56  isolated-center  ['barget.wav', 'jeelow.wav', 'goorshell.wav', ...
#  57  isolated-center  ['barget.wav', 'jeelow.wav', 'fisslin.wav', 'l...
#  58  isolated-center  ['rakken.wav', 'chelad.wav', 'pakrid.wav', 'li...
#  59  isolated-center  ['sumbark.wav', 'jeelow.wav', 'haagle.wav', 'l...
#
#                                         image_sequence
#  40   ['Picture2.png', 'Picture6.png', 'Picture3.png']
#  41   ['Picture2.png', 'Picture4.png', 'Picture3.png']
#  42   ['Picture8.png', 'Picture6.png', 'Picture7.png']
#  43  ['Picture10.png', 'Picture1.png', 'Picture3.png']
#  44   ['Picture9.png', 'Picture5.png', 'Picture1.png']
#  45   ['Picture2.png', 'Picture4.png', 'Picture9.png']
#  46   ['Picture6.png', 'Picture5.png', 'Picture7.png']
#  47   ['Picture2.png', 'Picture6.png', 'Picture7.png']
#  48   ['Picture5.png', 'Picture4.png', 'Picture7.png']
#  49   ['Picture1.png', 'Picture3.png', 'Picture2.png']
#  50  ['Picture10.png', 'Picture1.png', 'Picture5.png']
#  51   ['Picture8.png', 'Picture9.png', 'Picture1.png']
#  52   ['Picture7.png', 'Picture9.png', 'Picture4.png']
#  53  ['Picture9.png', 'Picture1.png', 'Picture10.png']
#  54   ['Picture4.png', 'Picture2.png', 'Picture1.png']
#  55  ['Picture3.png', 'Picture1.png', 'Picture10.png']
#  56   ['Picture8.png', 'Picture5.png', 'Picture4.png']
#  57   ['Picture8.png', 'Picture9.png', 'Picture4.png']
#  58   ['Picture2.png', 'Picture3.png', 'Picture1.png']
#  59   ['Picture7.png', 'Picture1.png', 'Picture2.png']  ,
#  'isolated-right':     trial      item1      item2      item3 casemarker1 casemarker2  \
#  60      1     rakken     dingep     pakrid      chelad     limeber
#  61      2     rakken     makkot     pakrid     limeber      chelad
#  62      3     barget     dingep    sumbark     limeber      chelad
#  63      4     bimdah     haagle     pakrid      chelad     limeber
#  64      5    fisslin  goorshell     haagle      chelad     limeber
#  65      6     rakken     makkot    fisslin     limeber      chelad
#  66      7     dingep  goorshell    sumbark     limeber      chelad
#  67      8     rakken     dingep    sumbark     limeber      chelad
#  68      9  goorshell     makkot    sumbark     limeber      chelad
#  69     10     haagle     pakrid     rakken      chelad     limeber
#  70     11     bimdah     haagle  goorshell     limeber      chelad
#  71     12     barget    fisslin     haagle      chelad     limeber
#  72     13    sumbark    fisslin     makkot      chelad     limeber
#  73     14    fisslin     haagle     bimdah      chelad     limeber
#  74     15     makkot     rakken     haagle      chelad     limeber
#  75     16     pakrid     haagle     bimdah     limeber      chelad
#  76     17     barget  goorshell     makkot     limeber      chelad
#  77     18     barget    fisslin     makkot     limeber      chelad
#  78     19     rakken     pakrid     haagle      chelad     limeber
#  79     20    sumbark     haagle     rakken      chelad     limeber
#
#     casemarker3                                           final  \
#  60      jeelow      rakken chelad dingep limeber pakrid jeelow
#  61      jeelow      rakken limeber makkot chelad pakrid jeelow
#  62      jeelow     barget limeber dingep chelad sumbark jeelow
#  63      jeelow      bimdah chelad haagle limeber pakrid jeelow
#  64      jeelow  fisslin chelad goorshell limeber haagle jeelow
#  65      jeelow     rakken limeber makkot chelad fisslin jeelow
#  66      jeelow  dingep limeber goorshell chelad sumbark jeelow
#  67      jeelow     rakken limeber dingep chelad sumbark jeelow
#  68      jeelow  goorshell limeber makkot chelad sumbark jeelow
#  69      jeelow      haagle chelad pakrid limeber rakken jeelow
#  70      jeelow   bimdah limeber haagle chelad goorshell jeelow
#  71      jeelow     barget chelad fisslin limeber haagle jeelow
#  72      jeelow    sumbark chelad fisslin limeber makkot jeelow
#  73      jeelow     fisslin chelad haagle limeber bimdah jeelow
#  74      jeelow      makkot chelad rakken limeber haagle jeelow
#  75      jeelow      pakrid limeber haagle chelad bimdah jeelow
#  76      jeelow   barget limeber goorshell chelad makkot jeelow
#  77      jeelow     barget limeber fisslin chelad makkot jeelow
#  78      jeelow      rakken chelad pakrid limeber haagle jeelow
#  79      jeelow     sumbark chelad haagle limeber rakken jeelow
#
#           condition                                     audio_sequence  \
#  60  isolated-right  ['rakken.wav', 'chelad.wav', 'dingep.wav', 'li...
#  61  isolated-right  ['rakken.wav', 'limeber.wav', 'makkot.wav', 'c...
#  62  isolated-right  ['barget.wav', 'limeber.wav', 'dingep.wav', 'c...
#  63  isolated-right  ['bimdah.wav', 'chelad.wav', 'haagle.wav', 'li...
#  64  isolated-right  ['fisslin.wav', 'chelad.wav', 'goorshell.wav',...
#  65  isolated-right  ['rakken.wav', 'limeber.wav', 'makkot.wav', 'c...
#  66  isolated-right  ['dingep.wav', 'limeber.wav', 'goorshell.wav',...
#  67  isolated-right  ['rakken.wav', 'limeber.wav', 'dingep.wav', 'c...
#  68  isolated-right  ['goorshell.wav', 'limeber.wav', 'makkot.wav',...
#  69  isolated-right  ['haagle.wav', 'chelad.wav', 'pakrid.wav', 'li...
#  70  isolated-right  ['bimdah.wav', 'limeber.wav', 'haagle.wav', 'c...
#  71  isolated-right  ['barget.wav', 'chelad.wav', 'fisslin.wav', 'l...
#  72  isolated-right  ['sumbark.wav', 'chelad.wav', 'fisslin.wav', '...
#  73  isolated-right  ['fisslin.wav', 'chelad.wav', 'haagle.wav', 'l...
#  74  isolated-right  ['makkot.wav', 'chelad.wav', 'rakken.wav', 'li...
#  75  isolated-right  ['pakrid.wav', 'limeber.wav', 'haagle.wav', 'c...
#  76  isolated-right  ['barget.wav', 'limeber.wav', 'goorshell.wav',...
#  77  isolated-right  ['barget.wav', 'limeber.wav', 'fisslin.wav', '...
#  78  isolated-right  ['rakken.wav', 'chelad.wav', 'pakrid.wav', 'li...
#  79  isolated-right  ['sumbark.wav', 'chelad.wav', 'haagle.wav', 'l...
#
#                                         image_sequence
#  60   ['Picture2.png', 'Picture6.png', 'Picture3.png']
#  61   ['Picture2.png', 'Picture4.png', 'Picture3.png']
#  62   ['Picture8.png', 'Picture6.png', 'Picture7.png']
#  63  ['Picture10.png', 'Picture1.png', 'Picture3.png']
#  64   ['Picture9.png', 'Picture5.png', 'Picture1.png']
#  65   ['Picture2.png', 'Picture4.png', 'Picture9.png']
#  66   ['Picture6.png', 'Picture5.png', 'Picture7.png']
#  67   ['Picture2.png', 'Picture6.png', 'Picture7.png']
#  68   ['Picture5.png', 'Picture4.png', 'Picture7.png']
#  69   ['Picture1.png', 'Picture3.png', 'Picture2.png']
#  70  ['Picture10.png', 'Picture1.png', 'Picture5.png']
#  71   ['Picture8.png', 'Picture9.png', 'Picture1.png']
#  72   ['Picture7.png', 'Picture9.png', 'Picture4.png']
#  73  ['Picture9.png', 'Picture1.png', 'Picture10.png']
#  74   ['Picture4.png', 'Picture2.png', 'Picture1.png']
#  75  ['Picture3.png', 'Picture1.png', 'Picture10.png']
#  76   ['Picture8.png', 'Picture5.png', 'Picture4.png']
#  77   ['Picture8.png', 'Picture9.png', 'Picture4.png']
#  78   ['Picture2.png', 'Picture3.png', 'Picture1.png']
#  79   ['Picture7.png', 'Picture1.png', 'Picture2.png']  }

# %%
train_dfs['correlated']
# Out:
#     trial      item1      item2      item3 casemarker1 casemarker2  \
# 0       1     rakken     dingep     pakrid      nellby     limeber
# 1       2     rakken     makkot     pakrid      nellby     limeber
# 2       3     barget     dingep    sumbark      nellby     limeber
# 3       4     bimdah     haagle     pakrid      nellby     limeber
# 4       5    fisslin  goorshell     haagle      nellby     limeber
# 5       6     rakken     makkot    fisslin      nellby     limeber
# 6       7     dingep  goorshell    sumbark      nellby     limeber
# 7       8     rakken     dingep    sumbark      nellby     limeber
# 8       9  goorshell     makkot    sumbark      nellby     limeber
# 9      10     haagle     pakrid     rakken      nellby     limeber
# 10     11     bimdah     haagle  goorshell      nellby     limeber
# 11     12     barget    fisslin     haagle      nellby     limeber
# 12     13    sumbark    fisslin     makkot      nellby     limeber
# 13     14    fisslin     haagle     bimdah      nellby     limeber
# 14     15     makkot     rakken     haagle      nellby     limeber
# 15     16     pakrid     haagle     bimdah      nellby     limeber
# 16     17     barget  goorshell     makkot      nellby     limeber
# 17     18     barget    fisslin     makkot      nellby     limeber
# 18     19     rakken     pakrid     haagle      nellby     limeber
# 19     20    sumbark     haagle     rakken      nellby     limeber
#
#    casemarker3                                           final   condition  \
# 0       chelad      rakken nellby dingep limeber pakrid chelad  correlated
# 1       chelad      rakken nellby makkot limeber pakrid chelad  correlated
# 2       chelad     barget nellby dingep limeber sumbark chelad  correlated
# 3       chelad      bimdah nellby haagle limeber pakrid chelad  correlated
# 4       chelad  fisslin nellby goorshell limeber haagle chelad  correlated
# 5       chelad     rakken nellby makkot limeber fisslin chelad  correlated
# 6       chelad  dingep nellby goorshell limeber sumbark chelad  correlated
# 7       chelad     rakken nellby dingep limeber sumbark chelad  correlated
# 8       chelad  goorshell nellby makkot limeber sumbark chelad  correlated
# 9       chelad      haagle nellby pakrid limeber rakken chelad  correlated
# 10      chelad   bimdah nellby haagle limeber goorshell chelad  correlated
# 11      chelad     barget nellby fisslin limeber haagle chelad  correlated
# 12      chelad    sumbark nellby fisslin limeber makkot chelad  correlated
# 13      chelad     fisslin nellby haagle limeber bimdah chelad  correlated
# 14      chelad      makkot nellby rakken limeber haagle chelad  correlated
# 15      chelad      pakrid nellby haagle limeber bimdah chelad  correlated
# 16      chelad   barget nellby goorshell limeber makkot chelad  correlated
# 17      chelad     barget nellby fisslin limeber makkot chelad  correlated
# 18      chelad      rakken nellby pakrid limeber haagle chelad  correlated
# 19      chelad     sumbark nellby haagle limeber rakken chelad  correlated
#
#                                        audio_sequence
# 0   ['rakken.wav', 'nellby.wav', 'dingep.wav', 'li...
# 1   ['rakken.wav', 'nellby.wav', 'makkot.wav', 'li...
# 2   ['barget.wav', 'nellby.wav', 'dingep.wav', 'li...
# 3   ['bimdah.wav', 'nellby.wav', 'haagle.wav', 'li...
# 4   ['fisslin.wav', 'nellby.wav', 'goorshell.wav',...
# 5   ['rakken.wav', 'nellby.wav', 'makkot.wav', 'li...
# 6   ['dingep.wav', 'nellby.wav', 'goorshell.wav', ...
# 7   ['rakken.wav', 'nellby.wav', 'dingep.wav', 'li...
# 8   ['goorshell.wav', 'nellby.wav', 'makkot.wav', ...
# 9   ['haagle.wav', 'nellby.wav', 'pakrid.wav', 'li...
# 10  ['bimdah.wav', 'nellby.wav', 'haagle.wav', 'li...
# 11  ['barget.wav', 'nellby.wav', 'fisslin.wav', 'l...
# 12  ['sumbark.wav', 'nellby.wav', 'fisslin.wav', '...
# 13  ['fisslin.wav', 'nellby.wav', 'haagle.wav', 'l...
# 14  ['makkot.wav', 'nellby.wav', 'rakken.wav', 'li...
# 15  ['pakrid.wav', 'nellby.wav', 'haagle.wav', 'li...
# 16  ['barget.wav', 'nellby.wav', 'goorshell.wav', ...
# 17  ['barget.wav', 'nellby.wav', 'fisslin.wav', 'l...
# 18  ['rakken.wav', 'nellby.wav', 'pakrid.wav', 'li...
# 19  ['sumbark.wav', 'nellby.wav', 'haagle.wav', 'l...

# %% [markdown]
# ### associating images

# %%
# Define the pool of syllabus items
import random
import os 
# Set seed for reproducibility
random.seed(123)
images = os.listdir('../../Images')
# .DS_Store
try:
    images.remove('.DS_Store')
except:
    pass

syllabus_pool = ["barget", "bimdah", "chelad", "dingep", "fisslin", "goorshell",
                "haagle", "jeelow", "limeber", "makkot", "nellby", "pakrid",
                "rakken", "sumbark"]

# Randomly select 10 items from the pool
selected_items = random.sample(syllabus_pool, 10)
selected_items

image_association = {}
for image, item in zip(images, selected_items):
    image_association[item] = image
    
image_association
# Out:
# {'barget': 'Picture8.png',
#  'fisslin': 'Picture9.png',
#  'bimdah': 'Picture10.png',
#  'haagle': 'Picture1.png',
#  'rakken': 'Picture2.png',
#  'pakrid': 'Picture3.png',
#  'sumbark': 'Picture7.png',
#  'dingep': 'Picture6.png',
#  'makkot': 'Picture4.png',
#  'goorshell': 'Picture5.png'}

# %%
df = train_dfs['correlated'].sample(frac=1)

# %%
block_data = {}
for i,row in enumerate(df.iterrows(),1):
    block_data['trial'] = i
    trial_data = row[1]
    print(trial_data)
    audio_items = eval(trial_data['audio_sequence'])
    images = eval(trial_data['image_sequence'])
    
    item1, casemarker1, item2, casemarker2, item3, casemarker3 = [os.path.join("./Audio", item) for item in audio_items]
    
    
    
    break
# Out:
# trial                                                             3
# item1                                                        barget
# item2                                                        dingep
# item3                                                       sumbark
# casemarker1                                                  chelad
# casemarker2                                                 limeber
# casemarker3                                                  jeelow
# final                   barget chelad dingep limeber sumbark jeelow
# condition                                                correlated
# audio_sequence    ['barget.wav', 'chelad.wav', 'dingep.wav', 'li...
# image_sequence     ['Picture8.png', 'Picture6.png', 'Picture7.png']
# Name: 2, dtype: object
# ['./Audio/barget.wav', './Audio/chelad.wav', './Audio/dingep.wav', './Audio/limeber.wav', './Audio/sumbark.wav', './Audio/jeelow.wav']

# %%
test['condition'].unique()
# Out:
# array(['correlated', 'isolated-left', 'isolated-center', 'isolated-right'],
#       dtype=object)

# %%
test_dfs = {}
for condition in test['condition'].unique():
        print(f"- {condition}")
        test_dfs[condition] = test[test['condition']==condition]
        
test_dfs
# Out:
# - correlated
# - isolated-left
# - isolated-center
# - isolated-right
# {'correlated':     trial      item1    item2    item3 casemarker1 casemarker2 casemarker3  \
#  0      40     bimdah   dingep   pakrid      chelad      jeelow      nellby
#  1      47    sumbark   makkot   pakrid      chelad      jeelow      nellby
#  2      20     dingep  fisslin   haagle      chelad      jeelow      nellby
#  3      43     makkot   bimdah  sumbark      chelad      jeelow      nellby
#  4      31    sumbark   pakrid   barget      chelad      jeelow      nellby
#  5      36    fisslin   barget  sumbark      chelad      jeelow      nellby
#  6      14     barget   rakken  fisslin      chelad      jeelow      nellby
#  7      18     pakrid  fisslin  sumbark      chelad      jeelow      nellby
#  8      45     makkot   pakrid   dingep      chelad      jeelow      nellby
#  9      25    fisslin   dingep   rakken      chelad      jeelow      nellby
#  10     28     barget   dingep  fisslin      chelad      jeelow      nellby
#  11     12  goorshell  sumbark  fisslin      chelad      jeelow      nellby
#
#                                               final   condition  foil_category  \
#  0        bimdah chelad dingep jeelow pakrid nellby  correlated  transposition
#  1       sumbark chelad makkot jeelow pakrid nellby  correlated  transposition
#  2       dingep chelad fisslin jeelow haagle nellby  correlated  transposition
#  3       makkot chelad bimdah jeelow sumbark nellby  correlated  transposition
#  4       sumbark chelad pakrid jeelow barget nellby  correlated  transposition
#  5      fisslin chelad barget jeelow sumbark nellby  correlated  transposition
#  6       barget chelad rakken jeelow fisslin nellby  correlated     itemchange
#  7      pakrid chelad fisslin jeelow sumbark nellby  correlated     itemchange
#  8        makkot chelad pakrid jeelow dingep nellby  correlated     itemchange
#  9       fisslin chelad dingep jeelow rakken nellby  correlated     itemchange
#  10      barget chelad dingep jeelow fisslin nellby  correlated     itemchange
#  11  goorshell chelad sumbark jeelow fisslin nellby  correlated     itemchange
#
#                                  foil  \
#  0     ['dingep', 'bimdah', 'pakrid']
#  1    ['pakrid', 'makkot', 'sumbark']
#  2    ['fisslin', 'dingep', 'haagle']
#  3    ['sumbark', 'makkot', 'bimdah']
#  4    ['barget', 'sumbark', 'pakrid']
#  5   ['sumbark', 'fisslin', 'barget']
#  6    ['barget', 'makkot', 'fisslin']
#  7    ['pakrid', 'fisslin', 'dingep']
#  8     ['makkot', 'rakken', 'dingep']
#  9    ['fisslin', 'makkot', 'rakken']
#  10   ['barget', 'haagle', 'fisslin']
#  11  ['dingep', 'sumbark', 'fisslin']
#
#                                  target_audio_sequence  \
#  0   ['bimdah.wav', 'chelad.wav', 'dingep.wav', 'je...
#  1   ['sumbark.wav', 'chelad.wav', 'makkot.wav', 'j...
#  2   ['dingep.wav', 'chelad.wav', 'fisslin.wav', 'j...
#  3   ['makkot.wav', 'chelad.wav', 'bimdah.wav', 'je...
#  4   ['sumbark.wav', 'chelad.wav', 'pakrid.wav', 'j...
#  5   ['fisslin.wav', 'chelad.wav', 'barget.wav', 'j...
#  6   ['barget.wav', 'chelad.wav', 'rakken.wav', 'je...
#  7   ['pakrid.wav', 'chelad.wav', 'fisslin.wav', 'j...
#  8   ['makkot.wav', 'chelad.wav', 'pakrid.wav', 'je...
#  9   ['fisslin.wav', 'chelad.wav', 'dingep.wav', 'j...
#  10  ['barget.wav', 'chelad.wav', 'dingep.wav', 'je...
#  11  ['goorshell.wav', 'chelad.wav', 'sumbark.wav',...
#
#                                  target_image_sequence  \
#  0   ['Picture10.png', 'Picture6.png', 'Picture3.png']
#  1    ['Picture7.png', 'Picture4.png', 'Picture3.png']
#  2    ['Picture6.png', 'Picture9.png', 'Picture1.png']
#  3   ['Picture4.png', 'Picture10.png', 'Picture7.png']
#  4    ['Picture7.png', 'Picture3.png', 'Picture8.png']
#  5    ['Picture9.png', 'Picture8.png', 'Picture7.png']
#  6    ['Picture8.png', 'Picture2.png', 'Picture9.png']
#  7    ['Picture3.png', 'Picture9.png', 'Picture7.png']
#  8    ['Picture4.png', 'Picture3.png', 'Picture6.png']
#  9    ['Picture9.png', 'Picture6.png', 'Picture2.png']
#  10   ['Picture8.png', 'Picture6.png', 'Picture9.png']
#  11   ['Picture5.png', 'Picture7.png', 'Picture9.png']
#
#                                    foil_image_sequence
#  0   ['Picture6.png', 'Picture10.png', 'Picture3.png']
#  1    ['Picture3.png', 'Picture4.png', 'Picture7.png']
#  2    ['Picture9.png', 'Picture6.png', 'Picture1.png']
#  3   ['Picture7.png', 'Picture4.png', 'Picture10.png']
#  4    ['Picture8.png', 'Picture7.png', 'Picture3.png']
#  5    ['Picture7.png', 'Picture9.png', 'Picture8.png']
#  6    ['Picture8.png', 'Picture4.png', 'Picture9.png']
#  7    ['Picture3.png', 'Picture9.png', 'Picture6.png']
#  8    ['Picture4.png', 'Picture2.png', 'Picture6.png']
#  9    ['Picture9.png', 'Picture4.png', 'Picture2.png']
#  10   ['Picture8.png', 'Picture1.png', 'Picture9.png']
#  11   ['Picture6.png', 'Picture7.png', 'Picture9.png']  ,
#  'isolated-left':     trial    item1    item2      item3 casemarker1 casemarker2 casemarker3  \
#  12     37   bimdah   barget     pakrid      chelad      jeelow      nellby
#  13     38   bimdah   makkot  goorshell      chelad      jeelow      nellby
#  14     13   haagle   dingep    sumbark      chelad      jeelow      nellby
#  15      7   rakken   pakrid    sumbark      chelad      jeelow      nellby
#  16     41   rakken   barget    fisslin      chelad      nellby      jeelow
#  17     47  sumbark   makkot     pakrid      chelad      jeelow      nellby
#  18     21  sumbark   dingep     bimdah      chelad      jeelow      nellby
#  19     29   rakken   makkot     bimdah      chelad      jeelow      nellby
#  20     33  sumbark   bimdah     makkot      chelad      jeelow      nellby
#  21     42   rakken   barget     makkot      chelad      nellby      jeelow
#  22     14   barget   rakken    fisslin      chelad      jeelow      nellby
#  23     15   bimdah  fisslin  goorshell      chelad      nellby      jeelow
#
#                                              final      condition  \
#  12      bimdah chelad barget jeelow pakrid nellby  isolated-left
#  13   bimdah chelad makkot jeelow goorshell nellby  isolated-left
#  14     haagle chelad dingep jeelow sumbark nellby  isolated-left
#  15     rakken chelad pakrid jeelow sumbark nellby  isolated-left
#  16     rakken chelad barget nellby fisslin jeelow  isolated-left
#  17     sumbark chelad makkot jeelow pakrid nellby  isolated-left
#  18     sumbark chelad dingep jeelow bimdah nellby  isolated-left
#  19      rakken chelad makkot jeelow bimdah nellby  isolated-left
#  20     sumbark chelad bimdah jeelow makkot nellby  isolated-left
#  21      rakken chelad barget nellby makkot jeelow  isolated-left
#  22     barget chelad rakken jeelow fisslin nellby  isolated-left
#  23  bimdah chelad fisslin nellby goorshell jeelow  isolated-left
#
#      foil_category                               foil  \
#  12  transposition     ['bimdah', 'pakrid', 'barget']
#  13  transposition  ['makkot', 'goorshell', 'bimdah']
#  14  transposition    ['sumbark', 'dingep', 'haagle']
#  15  transposition    ['sumbark', 'rakken', 'pakrid']
#  16  transposition    ['barget', 'fisslin', 'rakken']
#  17  transposition    ['pakrid', 'sumbark', 'makkot']
#  18     itemchange     ['rakken', 'dingep', 'bimdah']
#  19     itemchange  ['goorshell', 'makkot', 'bimdah']
#  20     itemchange    ['sumbark', 'rakken', 'makkot']
#  21     itemchange     ['rakken', 'barget', 'bimdah']
#  22     itemchange    ['makkot', 'rakken', 'fisslin']
#  23     itemchange    ['bimdah', 'fisslin', 'rakken']
#
#                                  target_audio_sequence  \
#  12  ['bimdah.wav', 'chelad.wav', 'barget.wav', 'je...
#  13  ['bimdah.wav', 'chelad.wav', 'makkot.wav', 'je...
#  14  ['haagle.wav', 'chelad.wav', 'dingep.wav', 'je...
#  15  ['rakken.wav', 'chelad.wav', 'pakrid.wav', 'je...
#  16  ['rakken.wav', 'chelad.wav', 'barget.wav', 'ne...
#  17  ['sumbark.wav', 'chelad.wav', 'makkot.wav', 'j...
#  18  ['sumbark.wav', 'chelad.wav', 'dingep.wav', 'j...
#  19  ['rakken.wav', 'chelad.wav', 'makkot.wav', 'je...
#  20  ['sumbark.wav', 'chelad.wav', 'bimdah.wav', 'j...
#  21  ['rakken.wav', 'chelad.wav', 'barget.wav', 'ne...
#  22  ['barget.wav', 'chelad.wav', 'rakken.wav', 'je...
#  23  ['bimdah.wav', 'chelad.wav', 'fisslin.wav', 'n...
#
#                                  target_image_sequence  \
#  12  ['Picture10.png', 'Picture8.png', 'Picture3.png']
#  13  ['Picture10.png', 'Picture4.png', 'Picture5.png']
#  14   ['Picture1.png', 'Picture6.png', 'Picture7.png']
#  15   ['Picture2.png', 'Picture3.png', 'Picture7.png']
#  16   ['Picture2.png', 'Picture8.png', 'Picture9.png']
#  17   ['Picture7.png', 'Picture4.png', 'Picture3.png']
#  18  ['Picture7.png', 'Picture6.png', 'Picture10.png']
#  19  ['Picture2.png', 'Picture4.png', 'Picture10.png']
#  20  ['Picture7.png', 'Picture10.png', 'Picture4.png']
#  21   ['Picture2.png', 'Picture8.png', 'Picture4.png']
#  22   ['Picture8.png', 'Picture2.png', 'Picture9.png']
#  23  ['Picture10.png', 'Picture9.png', 'Picture5.png']
#
#                                    foil_image_sequence
#  12  ['Picture10.png', 'Picture3.png', 'Picture8.png']
#  13  ['Picture4.png', 'Picture5.png', 'Picture10.png']
#  14   ['Picture7.png', 'Picture6.png', 'Picture1.png']
#  15   ['Picture7.png', 'Picture2.png', 'Picture3.png']
#  16   ['Picture8.png', 'Picture9.png', 'Picture2.png']
#  17   ['Picture3.png', 'Picture7.png', 'Picture4.png']
#  18  ['Picture2.png', 'Picture6.png', 'Picture10.png']
#  19  ['Picture5.png', 'Picture4.png', 'Picture10.png']
#  20   ['Picture7.png', 'Picture2.png', 'Picture4.png']
#  21  ['Picture2.png', 'Picture8.png', 'Picture10.png']
#  22   ['Picture4.png', 'Picture2.png', 'Picture9.png']
#  23  ['Picture10.png', 'Picture9.png', 'Picture2.png']  ,
#  'isolated-center':     trial      item1      item2      item3 casemarker1 casemarker2  \
#  24     39     makkot     haagle    fisslin      chelad      jeelow
#  25     26     pakrid     barget  goorshell      chelad      jeelow
#  26      1     barget    sumbark     makkot      chelad      jeelow
#  27     10     haagle    fisslin     bimdah      chelad      jeelow
#  28     23     dingep  goorshell     rakken      chelad      jeelow
#  29     47    sumbark     makkot     pakrid      nellby      jeelow
#  30     48  goorshell     makkot     haagle      chelad      jeelow
#  31      2     bimdah     barget     makkot      nellby      jeelow
#  32     16    fisslin     haagle  goorshell      chelad      jeelow
#  33     42     rakken     barget     makkot      chelad      jeelow
#  34      8     pakrid  goorshell    sumbark      nellby      jeelow
#  35     14     barget     rakken    fisslin      chelad      jeelow
#
#     casemarker3                                          final  \
#  24      nellby     makkot chelad haagle jeelow fisslin nellby
#  25      nellby   pakrid chelad barget jeelow goorshell nellby
#  26      nellby     barget chelad sumbark jeelow makkot nellby
#  27      nellby     haagle chelad fisslin jeelow bimdah nellby
#  28      nellby   dingep chelad goorshell jeelow rakken nellby
#  29      chelad     sumbark nellby makkot jeelow pakrid chelad
#  30      nellby   goorshell chelad makkot jeelow haagle nellby
#  31      chelad      bimdah nellby barget jeelow makkot chelad
#  32      nellby  fisslin chelad haagle jeelow goorshell nellby
#  33      nellby      rakken chelad barget jeelow makkot nellby
#  34      chelad  pakrid nellby goorshell jeelow sumbark chelad
#  35      nellby     barget chelad rakken jeelow fisslin nellby
#
#            condition  foil_category                                 foil  \
#  24  isolated-center  transposition      ['haagle', 'makkot', 'fisslin']
#  25  isolated-center  transposition    ['goorshell', 'barget', 'pakrid']
#  26  isolated-center  transposition      ['sumbark', 'barget', 'makkot']
#  27  isolated-center  transposition      ['bimdah', 'fisslin', 'haagle']
#  28  isolated-center  transposition    ['dingep', 'rakken', 'goorshell']
#  29  isolated-center  transposition      ['pakrid', 'makkot', 'sumbark']
#  30  isolated-center     itemchange    ['goorshell', 'barget', 'haagle']
#  31  isolated-center     itemchange      ['bimdah', 'sumbark', 'makkot']
#  32  isolated-center     itemchange  ['fisslin', 'sumbark', 'goorshell']
#  33  isolated-center     itemchange    ['rakken', 'barget', 'goorshell']
#  34  isolated-center     itemchange   ['dingep', 'goorshell', 'sumbark']
#  35  isolated-center     itemchange      ['dingep', 'rakken', 'fisslin']
#
#                                  target_audio_sequence  \
#  24  ['makkot.wav', 'chelad.wav', 'haagle.wav', 'je...
#  25  ['pakrid.wav', 'chelad.wav', 'barget.wav', 'je...
#  26  ['barget.wav', 'chelad.wav', 'sumbark.wav', 'j...
#  27  ['haagle.wav', 'chelad.wav', 'fisslin.wav', 'j...
#  28  ['dingep.wav', 'chelad.wav', 'goorshell.wav', ...
#  29  ['sumbark.wav', 'nellby.wav', 'makkot.wav', 'j...
#  30  ['goorshell.wav', 'chelad.wav', 'makkot.wav', ...
#  31  ['bimdah.wav', 'nellby.wav', 'barget.wav', 'je...
#  32  ['fisslin.wav', 'chelad.wav', 'haagle.wav', 'j...
#  33  ['rakken.wav', 'chelad.wav', 'barget.wav', 'je...
#  34  ['pakrid.wav', 'nellby.wav', 'goorshell.wav', ...
#  35  ['barget.wav', 'chelad.wav', 'rakken.wav', 'je...
#
#                                  target_image_sequence  \
#  24   ['Picture4.png', 'Picture1.png', 'Picture9.png']
#  25   ['Picture3.png', 'Picture8.png', 'Picture5.png']
#  26   ['Picture8.png', 'Picture7.png', 'Picture4.png']
#  27  ['Picture1.png', 'Picture9.png', 'Picture10.png']
#  28   ['Picture6.png', 'Picture5.png', 'Picture2.png']
#  29   ['Picture7.png', 'Picture4.png', 'Picture3.png']
#  30   ['Picture5.png', 'Picture4.png', 'Picture1.png']
#  31  ['Picture10.png', 'Picture8.png', 'Picture4.png']
#  32   ['Picture9.png', 'Picture1.png', 'Picture5.png']
#  33   ['Picture2.png', 'Picture8.png', 'Picture4.png']
#  34   ['Picture3.png', 'Picture5.png', 'Picture7.png']
#  35   ['Picture8.png', 'Picture2.png', 'Picture9.png']
#
#                                    foil_image_sequence
#  24   ['Picture1.png', 'Picture4.png', 'Picture9.png']
#  25   ['Picture5.png', 'Picture8.png', 'Picture3.png']
#  26   ['Picture7.png', 'Picture8.png', 'Picture4.png']
#  27  ['Picture10.png', 'Picture9.png', 'Picture1.png']
#  28   ['Picture6.png', 'Picture2.png', 'Picture5.png']
#  29   ['Picture3.png', 'Picture4.png', 'Picture7.png']
#  30   ['Picture5.png', 'Picture8.png', 'Picture1.png']
#  31  ['Picture10.png', 'Picture7.png', 'Picture4.png']
#  32   ['Picture9.png', 'Picture7.png', 'Picture5.png']
#  33   ['Picture2.png', 'Picture8.png', 'Picture5.png']
#  34   ['Picture6.png', 'Picture5.png', 'Picture7.png']
#  35   ['Picture6.png', 'Picture2.png', 'Picture9.png']  ,
#  'isolated-right':     trial      item1      item2      item3 casemarker1 casemarker2  \
#  36     15     bimdah    fisslin  goorshell      jeelow      chelad
#  37     14     barget     rakken    fisslin      jeelow      chelad
#  38     22     haagle     barget     bimdah      chelad      jeelow
#  39      4     dingep     haagle     pakrid      chelad      jeelow
#  40     23     dingep  goorshell     rakken      chelad      jeelow
#  41     41     rakken     barget    fisslin      jeelow      chelad
#  42     40     bimdah     dingep     pakrid      jeelow      chelad
#  43     34  goorshell     haagle     dingep      chelad      jeelow
#  44     18     pakrid    fisslin    sumbark      jeelow      chelad
#  45      6     bimdah     makkot    fisslin      jeelow      chelad
#  46     35     dingep    sumbark     makkot      chelad      jeelow
#  47     43     makkot     bimdah    sumbark      chelad      jeelow
#
#     casemarker3                                          final       condition  \
#  36      nellby  bimdah jeelow fisslin chelad goorshell nellby  isolated-right
#  37      nellby     barget jeelow rakken chelad fisslin nellby  isolated-right
#  38      nellby      haagle chelad barget jeelow bimdah nellby  isolated-right
#  39      nellby      dingep chelad haagle jeelow pakrid nellby  isolated-right
#  40      nellby   dingep chelad goorshell jeelow rakken nellby  isolated-right
#  41      nellby     rakken jeelow barget chelad fisslin nellby  isolated-right
#  42      nellby      bimdah jeelow dingep chelad pakrid nellby  isolated-right
#  43      nellby   goorshell chelad haagle jeelow dingep nellby  isolated-right
#  44      nellby    pakrid jeelow fisslin chelad sumbark nellby  isolated-right
#  45      nellby     bimdah jeelow makkot chelad fisslin nellby  isolated-right
#  46      nellby     dingep chelad sumbark jeelow makkot nellby  isolated-right
#  47      nellby     makkot chelad bimdah jeelow sumbark nellby  isolated-right
#
#      foil_category                                foil  \
#  36  transposition  ['goorshell', 'fisslin', 'bimdah']
#  37  transposition     ['fisslin', 'barget', 'rakken']
#  38  transposition      ['barget', 'bimdah', 'haagle']
#  39  transposition      ['pakrid', 'haagle', 'dingep']
#  40  transposition   ['dingep', 'rakken', 'goorshell']
#  41  transposition     ['rakken', 'fisslin', 'barget']
#  42     itemchange      ['bimdah', 'barget', 'pakrid']
#  43     itemchange      ['bimdah', 'haagle', 'dingep']
#  44     itemchange     ['pakrid', 'fisslin', 'bimdah']
#  45     itemchange      ['bimdah', 'makkot', 'rakken']
#  46     itemchange     ['barget', 'sumbark', 'makkot']
#  47     itemchange     ['makkot', 'pakrid', 'sumbark']
#
#                                  target_audio_sequence  \
#  36  ['bimdah.wav', 'jeelow.wav', 'fisslin.wav', 'c...
#  37  ['barget.wav', 'jeelow.wav', 'rakken.wav', 'ch...
#  38  ['haagle.wav', 'chelad.wav', 'barget.wav', 'je...
#  39  ['dingep.wav', 'chelad.wav', 'haagle.wav', 'je...
#  40  ['dingep.wav', 'chelad.wav', 'goorshell.wav', ...
#  41  ['rakken.wav', 'jeelow.wav', 'barget.wav', 'ch...
#  42  ['bimdah.wav', 'jeelow.wav', 'dingep.wav', 'ch...
#  43  ['goorshell.wav', 'chelad.wav', 'haagle.wav', ...
#  44  ['pakrid.wav', 'jeelow.wav', 'fisslin.wav', 'c...
#  45  ['bimdah.wav', 'jeelow.wav', 'makkot.wav', 'ch...
#  46  ['dingep.wav', 'chelad.wav', 'sumbark.wav', 'j...
#  47  ['makkot.wav', 'chelad.wav', 'bimdah.wav', 'je...
#
#                                  target_image_sequence  \
#  36  ['Picture10.png', 'Picture9.png', 'Picture5.png']
#  37   ['Picture8.png', 'Picture2.png', 'Picture9.png']
#  38  ['Picture1.png', 'Picture8.png', 'Picture10.png']
#  39   ['Picture6.png', 'Picture1.png', 'Picture3.png']
#  40   ['Picture6.png', 'Picture5.png', 'Picture2.png']
#  41   ['Picture2.png', 'Picture8.png', 'Picture9.png']
#  42  ['Picture10.png', 'Picture6.png', 'Picture3.png']
#  43   ['Picture5.png', 'Picture1.png', 'Picture6.png']
#  44   ['Picture3.png', 'Picture9.png', 'Picture7.png']
#  45  ['Picture10.png', 'Picture4.png', 'Picture9.png']
#  46   ['Picture6.png', 'Picture7.png', 'Picture4.png']
#  47  ['Picture4.png', 'Picture10.png', 'Picture7.png']
#
#                                    foil_image_sequence
#  36  ['Picture5.png', 'Picture9.png', 'Picture10.png']
#  37   ['Picture9.png', 'Picture8.png', 'Picture2.png']
#  38  ['Picture8.png', 'Picture10.png', 'Picture1.png']
#  39   ['Picture3.png', 'Picture1.png', 'Picture6.png']
#  40   ['Picture6.png', 'Picture2.png', 'Picture5.png']
#  41   ['Picture2.png', 'Picture9.png', 'Picture8.png']
#  42  ['Picture10.png', 'Picture8.png', 'Picture3.png']
#  43  ['Picture10.png', 'Picture1.png', 'Picture6.png']
#  44  ['Picture3.png', 'Picture9.png', 'Picture10.png']
#  45  ['Picture10.png', 'Picture4.png', 'Picture2.png']
#  46   ['Picture8.png', 'Picture7.png', 'Picture4.png']
#  47   ['Picture4.png', 'Picture3.png', 'Picture7.png']  }

# %%
for i,row in enumerate(test_dfs['correlated'].iloc[:1,:].iterrows(),1):
    trial_data = row[1]
    target_images = eval(trial_data['target_image_sequence'])
    foil_images = eval(trial_data['foil_image_sequence'])
    
    
    
    print(trial_data)
    break
# Out:
# trial                                                                   40
# item1                                                               bimdah
# item2                                                               dingep
# item3                                                               pakrid
# casemarker1                                                         chelad
# casemarker2                                                         jeelow
# casemarker3                                                         nellby
# final                            bimdah chelad dingep jeelow pakrid nellby
# condition                                                       correlated
# foil_category                                                transposition
# foil                                        ['dingep', 'bimdah', 'pakrid']
# target_audio_sequence    ['bimdah.wav', 'chelad.wav', 'dingep.wav', 'je...
# target_image_sequence    ['Picture10.png', 'Picture6.png', 'Picture3.png']
# foil_image_sequence      ['Picture6.png', 'Picture10.png', 'Picture3.png']
# Name: 0, dtype: object
