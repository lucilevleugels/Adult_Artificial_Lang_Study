# %%
# import random
# from itertools import permutations
# import pandas as pd

# # Set seed for reproducibility
# random.seed(123)

# # Define the pool of syllabus items
# syllabus_pool = ["barget", "bimdah", "chelad", "dingep", "fisslin", "goorshell",
#                  "haagle", "jeelow", "limeber", "makkot", "nellby", "pakrid",
#                  "rakken", "sumbark"]

# # Randomly select 10 items from the pool
# selected_items = random.sample(syllabus_pool, 10)

# # Generate all possible permutations of the selected items
# all_permutations = list(permutations(selected_items, 3))

# # Filter out invalid permutations (those with repeated items)
# valid_permutations = [p for p in all_permutations if len(set(p)) == len(p)]

# # Randomly select 20 valid permutations
# selected_permutations = random.sample(valid_permutations, 20)

# # Create the initial DataFrame
# df = pd.DataFrame({
#     'trial': range(1, 21),
#     'item1': [p[0] for p in selected_permutations],
#     'item2': [p[1] for p in selected_permutations],
#     'item3': [p[2] for p in selected_permutations]
# })

# # Identify remaining items for case markers
# remaining_items = list(set(syllabus_pool) - set(selected_items))

# # Randomly select 3 items to be used as case markers
# casemarker_items = random.sample(remaining_items, 3)

# # Add case markers to the DataFrame
# df['casemarker1'] = casemarker_items[0]
# df['casemarker2'] = casemarker_items[1]
# df['casemarker3'] = casemarker_items[2]

# # Create a concatenated column for items and case markers
# df['final'] = df['item1'] + " " + df['casemarker1'] + " " + df['item2'] + " " + df['casemarker2'] + " " + df['item3'] + " " + df['casemarker3']

# # Create a new DataFrame with swapped case markers
# df_new = df.copy()

# # Identify 50% of rows to swap in df_new
# swap_rows = random.sample(range(len(df_new)), int(len(df_new) * 0.5))

# # Swap casemarkers in df_new for the identified rows
# for row in swap_rows:
#     df_new.at[row, 'casemarker2'], df_new.at[row, 'casemarker3'] = df_new.at[row, 'casemarker3'], df_new.at[row, 'casemarker2']

# # Update the 'final' column in df_new
# df_new['final'] = df_new['item1'] + " " + df_new['casemarker1'] + " " + df_new['item2'] + " " + df_new['casemarker2'] + " " + df_new['item3'] + " " + df_new['casemarker3']


# # Label the conditions
# df['condition'] = "correlated"
# df_new['condition'] = "isolated"

# # Combine the original and new DataFrames
# combined_df = pd.concat([df, df_new], ignore_index=True)
# combined_df

# %%
import random
from itertools import permutations
import pandas as pd

# Set seed for reproducibility
random.seed(123)

# Define the pool of syllabus items
syllabus_pool = ["barget", "bimdah", "chelad", "dingep", "fisslin", "goorshell",
                 "haagle", "jeelow", "limeber", "makkot", "nellby", "pakrid",
                 "rakken", "sumbark"]

# Randomly select 10 items from the pool
selected_items = random.sample(syllabus_pool, 10)

# Generate all possible permutations of the selected items
all_permutations = list(permutations(selected_items, 3))

# Filter out invalid permutations (those with repeated items)
valid_permutations = [p for p in all_permutations if len(set(p)) == len(p)]

# Randomly select 20 valid permutations
selected_permutations = random.sample(valid_permutations, 20)

# Create the initial DataFrame
df = pd.DataFrame({
    'trial': range(1, 21),
    'item1': [p[0] for p in selected_permutations],
    'item2': [p[1] for p in selected_permutations],
    'item3': [p[2] for p in selected_permutations]
})

# Identify remaining items for case markers
remaining_items = list(set(syllabus_pool) - set(selected_items))

# Randomly select 3 items to be used as case markers
casemarker_items = random.sample(remaining_items, 3)

# Randomly select 3 items to be used as case markers
casemarker_items = random.sample(remaining_items, 3)

# Add case markers to the DataFrame
df['casemarker1'] = casemarker_items[0]
df['casemarker2'] = casemarker_items[1]
df['casemarker3'] = casemarker_items[2]

# Create a list of case marker combinations
case_marker_combinations = ["correlated", "isolated-left", "isolated-center", "isolated-right"]

# Create an empty list to store rows
rows = []

# Create rows for each combination of case markers
for combination in case_marker_combinations:
    # Create a new DataFrame with swapped case markers
    df_new = df.copy()
    
    # Function to swap case markers for a given row
    def swap_case_markers(row, combination):
        if combination == "isolated-left":
            row['casemarker2'], row['casemarker3'] = row['casemarker3'], row['casemarker2']
        elif combination == "isolated-center":
            row['casemarker1'], row['casemarker3'] = row['casemarker3'], row['casemarker1']
        elif combination == "isolated-right":
            row['casemarker1'], row['casemarker2'] = row['casemarker2'], row['casemarker1']
        return row

    # Identify 50% of rows to swap in df_new
    swap_rows = random.sample(range(len(df_new)), int(len(df_new) * 0.5))

    # Swap casemarkers in df_new for the identified rows
    for row in swap_rows:
        df_new.iloc[row] = swap_case_markers(df_new.iloc[row], combination)

    # Update the 'final' column in df_new
    df_new['final'] = df_new['item1'] + " " + df_new['casemarker1'] + " " + df_new['item2'] + " " + df_new['casemarker2'] + " " + df_new['item3'] + " " + df_new['casemarker3']

    # Label the conditions
    df_new['condition'] = combination
    
    rows.append(df_new)

# Combine the DataFrames for different combinations
combined_df = pd.concat(rows, ignore_index=True)
combined_df

# %%
combined_df[combined_df['condition'] == 'isolated-center']
# Out:
#     trial      item1      item2      item3 casemarker1 casemarker2  \
# 40      1     rakken     dingep     pakrid      nellby     limeber
# 41      2     rakken     makkot     pakrid      chelad     limeber
# 42      3     barget     dingep    sumbark      nellby     limeber
# 43      4     bimdah     haagle     pakrid      chelad     limeber
# 44      5    fisslin  goorshell     haagle      chelad     limeber
# 45      6     rakken     makkot    fisslin      nellby     limeber
# 46      7     dingep  goorshell    sumbark      chelad     limeber
# 47      8     rakken     dingep    sumbark      chelad     limeber
# 48      9  goorshell     makkot    sumbark      nellby     limeber
# 49     10     haagle     pakrid     rakken      chelad     limeber
# 50     11     bimdah     haagle  goorshell      nellby     limeber
# 51     12     barget    fisslin     haagle      chelad     limeber
# 52     13    sumbark    fisslin     makkot      chelad     limeber
# 53     14    fisslin     haagle     bimdah      nellby     limeber
# 54     15     makkot     rakken     haagle      chelad     limeber
# 55     16     pakrid     haagle     bimdah      nellby     limeber
# 56     17     barget  goorshell     makkot      nellby     limeber
# 57     18     barget    fisslin     makkot      nellby     limeber
# 58     19     rakken     pakrid     haagle      chelad     limeber
# 59     20    sumbark     haagle     rakken      nellby     limeber
#
#    casemarker3                                           final  \
# 40      chelad      rakken nellby dingep limeber pakrid chelad
# 41      nellby      rakken chelad makkot limeber pakrid nellby
# 42      chelad     barget nellby dingep limeber sumbark chelad
# 43      nellby      bimdah chelad haagle limeber pakrid nellby
# 44      nellby  fisslin chelad goorshell limeber haagle nellby
# 45      chelad     rakken nellby makkot limeber fisslin chelad
# 46      nellby  dingep chelad goorshell limeber sumbark nellby
# 47      nellby     rakken chelad dingep limeber sumbark nellby
# 48      chelad  goorshell nellby makkot limeber sumbark chelad
# 49      nellby      haagle chelad pakrid limeber rakken nellby
# 50      chelad   bimdah nellby haagle limeber goorshell chelad
# 51      nellby     barget chelad fisslin limeber haagle nellby
# 52      nellby    sumbark chelad fisslin limeber makkot nellby
# 53      chelad     fisslin nellby haagle limeber bimdah chelad
# 54      nellby      makkot chelad rakken limeber haagle nellby
# 55      chelad      pakrid nellby haagle limeber bimdah chelad
# 56      chelad   barget nellby goorshell limeber makkot chelad
# 57      chelad     barget nellby fisslin limeber makkot chelad
# 58      nellby      rakken chelad pakrid limeber haagle nellby
# 59      chelad     sumbark nellby haagle limeber rakken chelad
#
#           condition
# 40  isolated-center
# 41  isolated-center
# 42  isolated-center
# 43  isolated-center
# 44  isolated-center
# 45  isolated-center
# 46  isolated-center
# 47  isolated-center
# 48  isolated-center
# 49  isolated-center
# 50  isolated-center
# 51  isolated-center
# 52  isolated-center
# 53  isolated-center
# 54  isolated-center
# 55  isolated-center
# 56  isolated-center
# 57  isolated-center
# 58  isolated-center
# 59  isolated-center

# %% [markdown]
# #### Need to change isolated conditon to middle-right, left-right, left-middle

# %% [markdown]
# ### Foil Generation
# ##### generating foils (visual), they are two types of foil
# #### type 1 (6 trial each block): transposition. for example: ABC, can be transposed into two way: BCA, CAB
# #### type 2 (6 trial each block): one item change, for example: ABC can be paired with DBC (D is randomly chose from 10-3 = 7 possible symbols).
# #### There are a total of 3 possible changes (left place, middle, right place), creat two trials for each of the change

# %%
# Type1 
## GENERATING TEST SET
test_cond_corr = combined_df[combined_df['condition']=='correlated']
test_cond_iso_l = combined_df[combined_df['condition']=='isolated-left']
test_cond_iso_c = combined_df[combined_df['condition']=='isolated-center']
test_cond_iso_r = combined_df[combined_df['condition']=='isolated-right']

test_cond_corr = test_cond_corr.sample(n=12).reset_index(drop=True)
test_cond_iso_l = test_cond_iso_l.sample(n=12).reset_index(drop=True)
test_cond_iso_c = test_cond_iso_c.sample(n=12).reset_index(drop=True)
test_cond_iso_r = test_cond_iso_r.sample(n=12).reset_index(drop=True)

test_df = pd.concat([test_cond_corr, test_cond_iso_l,test_cond_iso_c,test_cond_iso_r], axis=0).reset_index(drop=True)

# foil_categories
# Define the item categories
foil_category_1 = ['transposition']*6
foil_category_2 = ['itemchange']*6

foil_categories = foil_category_1 + foil_category_2 + foil_category_1 + foil_category_2 +foil_category_1 + foil_category_2 + foil_category_1 + foil_category_2
test_df['foil_category'] = foil_categories

# %%
test_df[test_df['condition']=='isolated-left']
# Out:
#     trial      item1      item2    item3 casemarker1 casemarker2 casemarker3  \
# 12      5    fisslin  goorshell   haagle      chelad     limeber      nellby
# 13      7     dingep  goorshell  sumbark      chelad      nellby     limeber
# 14      3     barget     dingep  sumbark      chelad     limeber      nellby
# 15      9  goorshell     makkot  sumbark      chelad      nellby     limeber
# 16     20    sumbark     haagle   rakken      chelad      nellby     limeber
# 17     19     rakken     pakrid   haagle      chelad      nellby     limeber
# 18      2     rakken     makkot   pakrid      chelad     limeber      nellby
# 19      8     rakken     dingep  sumbark      chelad     limeber      nellby
# 20     14    fisslin     haagle   bimdah      chelad     limeber      nellby
# 21     15     makkot     rakken   haagle      chelad     limeber      nellby
# 22      1     rakken     dingep   pakrid      chelad      nellby     limeber
# 23      4     bimdah     haagle   pakrid      chelad     limeber      nellby
#
#                                              final      condition  \
# 12  fisslin chelad goorshell limeber haagle nellby  isolated-left
# 13  dingep chelad goorshell nellby sumbark limeber  isolated-left
# 14     barget chelad dingep limeber sumbark nellby  isolated-left
# 15  goorshell chelad makkot nellby sumbark limeber  isolated-left
# 16     sumbark chelad haagle nellby rakken limeber  isolated-left
# 17      rakken chelad pakrid nellby haagle limeber  isolated-left
# 18      rakken chelad makkot limeber pakrid nellby  isolated-left
# 19     rakken chelad dingep limeber sumbark nellby  isolated-left
# 20     fisslin chelad haagle limeber bimdah nellby  isolated-left
# 21      makkot chelad rakken limeber haagle nellby  isolated-left
# 22      rakken chelad dingep nellby pakrid limeber  isolated-left
# 23      bimdah chelad haagle limeber pakrid nellby  isolated-left
#
#     foil_category                          foil
# 12  transposition  [goorshell, haagle, fisslin]
# 13  transposition  [dingep, sumbark, goorshell]
# 14  transposition     [dingep, sumbark, barget]
# 15  transposition  [sumbark, makkot, goorshell]
# 16  transposition     [rakken, haagle, sumbark]
# 17  transposition      [pakrid, rakken, haagle]
# 18     itemchange      [haagle, makkot, pakrid]
# 19     itemchange  [goorshell, dingep, sumbark]
# 20     itemchange     [fisslin, barget, bimdah]
# 21     itemchange      [makkot, rakken, pakrid]
# 22     itemchange     [rakken, fisslin, pakrid]
# 23     itemchange      [bimdah, barget, pakrid]

# %%
import random
from itertools import permutations
def generate_transposition_foil(items,):
    

    cyclic_permutations = []

    for perm in permutations(items):
        cyclic_permutation = ','.join(perm)
        if cyclic_permutation not in cyclic_permutations:
            cyclic_permutations.append(cyclic_permutation)

    trans_foils = [[foil] for foil in cyclic_permutations[1:]]
    return trans_foils

# %%
test_df_transposition = test_df[test_df['foil_category']=='transposition']
test_df_itemchange = test_df[test_df['foil_category']=='itemchange']


# TRANSPOSITION
list_of_foils = []
print("Generating Transposition Foils.")
for row in test_df_transposition[['item1','item2','item3']].iterrows():
    target_items = row[1].to_list()
    trans_foils = generate_transposition_foil(target_items)
    trans_foils = [item[0].split(',') for item in trans_foils]
    transposition_foil = random.choice(trans_foils)
    list_of_foils.append(transposition_foil)
test_df_transposition['foil'] = list_of_foils

# ITEM CHANGE
print("Generating Item Change Foils.")
list_of_foils = []
for row in test_df_itemchange[['item1','item2','item3']].iterrows():
    target_items = row[1].to_list()
    ##print(target_items)
    possibilities =  list(set(selected_items) - set(target_items))
    #print(possibilities)
    item_change = random.choice(possibilities)
    positions = [0,1,2] # left, center, middle
    position_selection = random.choice(positions)
    #print(item_change)
    #print(position_selection)
    
    itemchange_foils = target_items
    itemchange_foils[position_selection] = item_change
    list_of_foils.append(itemchange_foils)
    
    
test_df_itemchange['foil'] = list_of_foils


# REORDERING 

test_df = pd.concat([test_df_transposition, test_df_itemchange],axis=0)

# reordering
corr_df = test_df[test_df['condition']=='correlated']
iso_left_df = test_df[test_df['condition']=='isolated-left']
iso_center_df = test_df[test_df['condition']=='isolated-center']
iso_right_df = test_df[test_df['condition']=='isolated-right']

final_test_df = pd.concat([corr_df,iso_left_df,iso_center_df,iso_right_df],axis=0)
final_test_df
# Out:
# Generating Transposition Foils.
# Generating Item Change Foils.
# /var/folders/5r/pnlff12n2d55g65_tnn3b1pw0000gn/T/ipykernel_41135/602159972.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df_transposition['foil'] = list_of_foils
# /var/folders/5r/pnlff12n2d55g65_tnn3b1pw0000gn/T/ipykernel_41135/602159972.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df_itemchange['foil'] = list_of_foils
#     trial      item1      item2      item3 casemarker1 casemarker2  \
# 0      15     makkot     rakken     haagle      chelad     limeber
# 1       5    fisslin  goorshell     haagle      chelad     limeber
# 2       9  goorshell     makkot    sumbark      chelad     limeber
# 3      10     haagle     pakrid     rakken      chelad     limeber
# 4       1     rakken     dingep     pakrid      chelad     limeber
# 5      16     pakrid     haagle     bimdah      chelad     limeber
# 6      14    fisslin     haagle     bimdah      chelad     limeber
# 7      13    sumbark    fisslin     makkot      chelad     limeber
# 8      12     barget    fisslin     haagle      chelad     limeber
# 9       7     dingep  goorshell    sumbark      chelad     limeber
# 10     18     barget    fisslin     makkot      chelad     limeber
# 11      6     rakken     makkot    fisslin      chelad     limeber
# 12      5    fisslin  goorshell     haagle      chelad     limeber
# 13      7     dingep  goorshell    sumbark      chelad      nellby
# 14      3     barget     dingep    sumbark      chelad     limeber
# 15      9  goorshell     makkot    sumbark      chelad      nellby
# 16     20    sumbark     haagle     rakken      chelad      nellby
# 17     19     rakken     pakrid     haagle      chelad      nellby
# 18      2     rakken     makkot     pakrid      chelad     limeber
# 19      8     rakken     dingep    sumbark      chelad     limeber
# 20     14    fisslin     haagle     bimdah      chelad     limeber
# 21     15     makkot     rakken     haagle      chelad     limeber
# 22      1     rakken     dingep     pakrid      chelad      nellby
# 23      4     bimdah     haagle     pakrid      chelad     limeber
# 24      1     rakken     dingep     pakrid      nellby     limeber
# 25      5    fisslin  goorshell     haagle      chelad     limeber
# 26      8     rakken     dingep    sumbark      chelad     limeber
# 27     13    sumbark    fisslin     makkot      chelad     limeber
# 28     12     barget    fisslin     haagle      chelad     limeber
# 29     14    fisslin     haagle     bimdah      nellby     limeber
# 30      6     rakken     makkot    fisslin      nellby     limeber
# 31     18     barget    fisslin     makkot      nellby     limeber
# 32      4     bimdah     haagle     pakrid      chelad     limeber
# 33     10     haagle     pakrid     rakken      chelad     limeber
# 34     19     rakken     pakrid     haagle      chelad     limeber
# 35     11     bimdah     haagle  goorshell      nellby     limeber
# 36      8     rakken     dingep    sumbark     limeber      chelad
# 37      1     rakken     dingep     pakrid      chelad     limeber
# 38     14    fisslin     haagle     bimdah      chelad     limeber
# 39      6     rakken     makkot    fisslin     limeber      chelad
# 40      2     rakken     makkot     pakrid     limeber      chelad
# 41     13    sumbark    fisslin     makkot      chelad     limeber
# 42      9  goorshell     makkot    sumbark     limeber      chelad
# 43     15     makkot     rakken     haagle      chelad     limeber
# 44     19     rakken     pakrid     haagle      chelad     limeber
# 45     20    sumbark     haagle     rakken      chelad     limeber
# 46      5    fisslin  goorshell     haagle      chelad     limeber
# 47      4     bimdah     haagle     pakrid      chelad     limeber
#
#    casemarker3                                           final  \
# 0       nellby      makkot chelad rakken limeber haagle nellby
# 1       nellby  fisslin chelad goorshell limeber haagle nellby
# 2       nellby  goorshell chelad makkot limeber sumbark nellby
# 3       nellby      haagle chelad pakrid limeber rakken nellby
# 4       nellby      rakken chelad dingep limeber pakrid nellby
# 5       nellby      pakrid chelad haagle limeber bimdah nellby
# 6       nellby     fisslin chelad haagle limeber bimdah nellby
# 7       nellby    sumbark chelad fisslin limeber makkot nellby
# 8       nellby     barget chelad fisslin limeber haagle nellby
# 9       nellby  dingep chelad goorshell limeber sumbark nellby
# 10      nellby     barget chelad fisslin limeber makkot nellby
# 11      nellby     rakken chelad makkot limeber fisslin nellby
# 12      nellby  fisslin chelad goorshell limeber haagle nellby
# 13     limeber  dingep chelad goorshell nellby sumbark limeber
# 14      nellby     barget chelad dingep limeber sumbark nellby
# 15     limeber  goorshell chelad makkot nellby sumbark limeber
# 16     limeber     sumbark chelad haagle nellby rakken limeber
# 17     limeber      rakken chelad pakrid nellby haagle limeber
# 18      nellby      rakken chelad makkot limeber pakrid nellby
# 19      nellby     rakken chelad dingep limeber sumbark nellby
# 20      nellby     fisslin chelad haagle limeber bimdah nellby
# 21      nellby      makkot chelad rakken limeber haagle nellby
# 22     limeber      rakken chelad dingep nellby pakrid limeber
# 23      nellby      bimdah chelad haagle limeber pakrid nellby
# 24      chelad      rakken nellby dingep limeber pakrid chelad
# 25      nellby  fisslin chelad goorshell limeber haagle nellby
# 26      nellby     rakken chelad dingep limeber sumbark nellby
# 27      nellby    sumbark chelad fisslin limeber makkot nellby
# 28      nellby     barget chelad fisslin limeber haagle nellby
# 29      chelad     fisslin nellby haagle limeber bimdah chelad
# 30      chelad     rakken nellby makkot limeber fisslin chelad
# 31      chelad     barget nellby fisslin limeber makkot chelad
# 32      nellby      bimdah chelad haagle limeber pakrid nellby
# 33      nellby      haagle chelad pakrid limeber rakken nellby
# 34      nellby      rakken chelad pakrid limeber haagle nellby
# 35      chelad   bimdah nellby haagle limeber goorshell chelad
# 36      nellby     rakken limeber dingep chelad sumbark nellby
# 37      nellby      rakken chelad dingep limeber pakrid nellby
# 38      nellby     fisslin chelad haagle limeber bimdah nellby
# 39      nellby     rakken limeber makkot chelad fisslin nellby
# 40      nellby      rakken limeber makkot chelad pakrid nellby
# 41      nellby    sumbark chelad fisslin limeber makkot nellby
# 42      nellby  goorshell limeber makkot chelad sumbark nellby
# 43      nellby      makkot chelad rakken limeber haagle nellby
# 44      nellby      rakken chelad pakrid limeber haagle nellby
# 45      nellby     sumbark chelad haagle limeber rakken nellby
# 46      nellby  fisslin chelad goorshell limeber haagle nellby
# 47      nellby      bimdah chelad haagle limeber pakrid nellby
#
#           condition  foil_category                          foil
# 0        correlated  transposition      [makkot, haagle, rakken]
# 1        correlated  transposition  [goorshell, haagle, fisslin]
# 2        correlated  transposition  [sumbark, makkot, goorshell]
# 3        correlated  transposition      [pakrid, haagle, rakken]
# 4        correlated  transposition      [pakrid, dingep, rakken]
# 5        correlated  transposition      [haagle, pakrid, bimdah]
# 6        correlated     itemchange  [fisslin, goorshell, bimdah]
# 7        correlated     itemchange     [rakken, fisslin, makkot]
# 8        correlated     itemchange      [barget, bimdah, haagle]
# 9        correlated     itemchange  [dingep, goorshell, fisslin]
# 10       correlated     itemchange     [barget, fisslin, haagle]
# 11       correlated     itemchange     [pakrid, makkot, fisslin]
# 12    isolated-left  transposition  [goorshell, haagle, fisslin]
# 13    isolated-left  transposition  [sumbark, dingep, goorshell]
# 14    isolated-left  transposition     [sumbark, barget, dingep]
# 15    isolated-left  transposition  [makkot, goorshell, sumbark]
# 16    isolated-left  transposition     [haagle, rakken, sumbark]
# 17    isolated-left  transposition      [haagle, pakrid, rakken]
# 18    isolated-left     itemchange      [bimdah, makkot, pakrid]
# 19    isolated-left     itemchange     [barget, dingep, sumbark]
# 20    isolated-left     itemchange      [rakken, haagle, bimdah]
# 21    isolated-left     itemchange      [dingep, rakken, haagle]
# 22    isolated-left     itemchange      [rakken, makkot, pakrid]
# 23    isolated-left     itemchange      [makkot, haagle, pakrid]
# 24  isolated-center  transposition      [rakken, pakrid, dingep]
# 25  isolated-center  transposition  [fisslin, haagle, goorshell]
# 26  isolated-center  transposition     [sumbark, rakken, dingep]
# 27  isolated-center  transposition    [makkot, fisslin, sumbark]
# 28  isolated-center  transposition     [haagle, fisslin, barget]
# 29  isolated-center  transposition     [bimdah, haagle, fisslin]
# 30  isolated-center     itemchange      [rakken, makkot, haagle]
# 31  isolated-center     itemchange     [barget, fisslin, pakrid]
# 32  isolated-center     itemchange      [makkot, haagle, pakrid]
# 33  isolated-center     itemchange      [haagle, pakrid, barget]
# 34  isolated-center     itemchange     [rakken, fisslin, haagle]
# 35  isolated-center     itemchange  [bimdah, sumbark, goorshell]
# 36   isolated-right  transposition     [dingep, sumbark, rakken]
# 37   isolated-right  transposition      [dingep, rakken, pakrid]
# 38   isolated-right  transposition     [bimdah, haagle, fisslin]
# 39   isolated-right  transposition     [rakken, fisslin, makkot]
# 40   isolated-right  transposition      [pakrid, rakken, makkot]
# 41   isolated-right  transposition    [makkot, sumbark, fisslin]
# 42   isolated-right     itemchange  [goorshell, barget, sumbark]
# 43   isolated-right     itemchange      [makkot, barget, haagle]
# 44   isolated-right     itemchange   [rakken, pakrid, goorshell]
# 45   isolated-right     itemchange    [sumbark, fisslin, rakken]
# 46   isolated-right     itemchange  [fisslin, goorshell, rakken]
# 47   isolated-right     itemchange      [bimdah, haagle, makkot]

# %%
final_test_df
# Out:
#     trial      item1      item2      item3 casemarker1 casemarker2  \
# 0      15     makkot     rakken     haagle      chelad     limeber
# 1       5    fisslin  goorshell     haagle      chelad     limeber
# 2       9  goorshell     makkot    sumbark      chelad     limeber
# 3      10     haagle     pakrid     rakken      chelad     limeber
# 4       1     rakken     dingep     pakrid      chelad     limeber
# 5      16     pakrid     haagle     bimdah      chelad     limeber
# 6      14    fisslin     haagle     bimdah      chelad     limeber
# 7      13    sumbark    fisslin     makkot      chelad     limeber
# 8      12     barget    fisslin     haagle      chelad     limeber
# 9       7     dingep  goorshell    sumbark      chelad     limeber
# 10     18     barget    fisslin     makkot      chelad     limeber
# 11      6     rakken     makkot    fisslin      chelad     limeber
# 12      5    fisslin  goorshell     haagle      chelad     limeber
# 13      7     dingep  goorshell    sumbark      chelad      nellby
# 14      3     barget     dingep    sumbark      chelad     limeber
# 15      9  goorshell     makkot    sumbark      chelad      nellby
# 16     20    sumbark     haagle     rakken      chelad      nellby
# 17     19     rakken     pakrid     haagle      chelad      nellby
# 18      2     rakken     makkot     pakrid      chelad     limeber
# 19      8     rakken     dingep    sumbark      chelad     limeber
# 20     14    fisslin     haagle     bimdah      chelad     limeber
# 21     15     makkot     rakken     haagle      chelad     limeber
# 22      1     rakken     dingep     pakrid      chelad      nellby
# 23      4     bimdah     haagle     pakrid      chelad     limeber
# 24      1     rakken     dingep     pakrid      nellby     limeber
# 25      5    fisslin  goorshell     haagle      chelad     limeber
# 26      8     rakken     dingep    sumbark      chelad     limeber
# 27     13    sumbark    fisslin     makkot      chelad     limeber
# 28     12     barget    fisslin     haagle      chelad     limeber
# 29     14    fisslin     haagle     bimdah      nellby     limeber
# 30      6     rakken     makkot    fisslin      nellby     limeber
# 31     18     barget    fisslin     makkot      nellby     limeber
# 32      4     bimdah     haagle     pakrid      chelad     limeber
# 33     10     haagle     pakrid     rakken      chelad     limeber
# 34     19     rakken     pakrid     haagle      chelad     limeber
# 35     11     bimdah     haagle  goorshell      nellby     limeber
# 36      8     rakken     dingep    sumbark     limeber      chelad
# 37      1     rakken     dingep     pakrid      chelad     limeber
# 38     14    fisslin     haagle     bimdah      chelad     limeber
# 39      6     rakken     makkot    fisslin     limeber      chelad
# 40      2     rakken     makkot     pakrid     limeber      chelad
# 41     13    sumbark    fisslin     makkot      chelad     limeber
# 42      9  goorshell     makkot    sumbark     limeber      chelad
# 43     15     makkot     rakken     haagle      chelad     limeber
# 44     19     rakken     pakrid     haagle      chelad     limeber
# 45     20    sumbark     haagle     rakken      chelad     limeber
# 46      5    fisslin  goorshell     haagle      chelad     limeber
# 47      4     bimdah     haagle     pakrid      chelad     limeber
#
#    casemarker3                                           final  \
# 0       nellby      makkot chelad rakken limeber haagle nellby
# 1       nellby  fisslin chelad goorshell limeber haagle nellby
# 2       nellby  goorshell chelad makkot limeber sumbark nellby
# 3       nellby      haagle chelad pakrid limeber rakken nellby
# 4       nellby      rakken chelad dingep limeber pakrid nellby
# 5       nellby      pakrid chelad haagle limeber bimdah nellby
# 6       nellby     fisslin chelad haagle limeber bimdah nellby
# 7       nellby    sumbark chelad fisslin limeber makkot nellby
# 8       nellby     barget chelad fisslin limeber haagle nellby
# 9       nellby  dingep chelad goorshell limeber sumbark nellby
# 10      nellby     barget chelad fisslin limeber makkot nellby
# 11      nellby     rakken chelad makkot limeber fisslin nellby
# 12      nellby  fisslin chelad goorshell limeber haagle nellby
# 13     limeber  dingep chelad goorshell nellby sumbark limeber
# 14      nellby     barget chelad dingep limeber sumbark nellby
# 15     limeber  goorshell chelad makkot nellby sumbark limeber
# 16     limeber     sumbark chelad haagle nellby rakken limeber
# 17     limeber      rakken chelad pakrid nellby haagle limeber
# 18      nellby      rakken chelad makkot limeber pakrid nellby
# 19      nellby     rakken chelad dingep limeber sumbark nellby
# 20      nellby     fisslin chelad haagle limeber bimdah nellby
# 21      nellby      makkot chelad rakken limeber haagle nellby
# 22     limeber      rakken chelad dingep nellby pakrid limeber
# 23      nellby      bimdah chelad haagle limeber pakrid nellby
# 24      chelad      rakken nellby dingep limeber pakrid chelad
# 25      nellby  fisslin chelad goorshell limeber haagle nellby
# 26      nellby     rakken chelad dingep limeber sumbark nellby
# 27      nellby    sumbark chelad fisslin limeber makkot nellby
# 28      nellby     barget chelad fisslin limeber haagle nellby
# 29      chelad     fisslin nellby haagle limeber bimdah chelad
# 30      chelad     rakken nellby makkot limeber fisslin chelad
# 31      chelad     barget nellby fisslin limeber makkot chelad
# 32      nellby      bimdah chelad haagle limeber pakrid nellby
# 33      nellby      haagle chelad pakrid limeber rakken nellby
# 34      nellby      rakken chelad pakrid limeber haagle nellby
# 35      chelad   bimdah nellby haagle limeber goorshell chelad
# 36      nellby     rakken limeber dingep chelad sumbark nellby
# 37      nellby      rakken chelad dingep limeber pakrid nellby
# 38      nellby     fisslin chelad haagle limeber bimdah nellby
# 39      nellby     rakken limeber makkot chelad fisslin nellby
# 40      nellby      rakken limeber makkot chelad pakrid nellby
# 41      nellby    sumbark chelad fisslin limeber makkot nellby
# 42      nellby  goorshell limeber makkot chelad sumbark nellby
# 43      nellby      makkot chelad rakken limeber haagle nellby
# 44      nellby      rakken chelad pakrid limeber haagle nellby
# 45      nellby     sumbark chelad haagle limeber rakken nellby
# 46      nellby  fisslin chelad goorshell limeber haagle nellby
# 47      nellby      bimdah chelad haagle limeber pakrid nellby
#
#           condition  foil_category                          foil
# 0        correlated  transposition      [makkot, haagle, rakken]
# 1        correlated  transposition  [goorshell, haagle, fisslin]
# 2        correlated  transposition  [sumbark, makkot, goorshell]
# 3        correlated  transposition      [pakrid, haagle, rakken]
# 4        correlated  transposition      [pakrid, dingep, rakken]
# 5        correlated  transposition      [haagle, pakrid, bimdah]
# 6        correlated     itemchange  [fisslin, goorshell, bimdah]
# 7        correlated     itemchange     [rakken, fisslin, makkot]
# 8        correlated     itemchange      [barget, bimdah, haagle]
# 9        correlated     itemchange  [dingep, goorshell, fisslin]
# 10       correlated     itemchange     [barget, fisslin, haagle]
# 11       correlated     itemchange     [pakrid, makkot, fisslin]
# 12    isolated-left  transposition  [goorshell, haagle, fisslin]
# 13    isolated-left  transposition  [sumbark, dingep, goorshell]
# 14    isolated-left  transposition     [sumbark, barget, dingep]
# 15    isolated-left  transposition  [makkot, goorshell, sumbark]
# 16    isolated-left  transposition     [haagle, rakken, sumbark]
# 17    isolated-left  transposition      [haagle, pakrid, rakken]
# 18    isolated-left     itemchange      [bimdah, makkot, pakrid]
# 19    isolated-left     itemchange     [barget, dingep, sumbark]
# 20    isolated-left     itemchange      [rakken, haagle, bimdah]
# 21    isolated-left     itemchange      [dingep, rakken, haagle]
# 22    isolated-left     itemchange      [rakken, makkot, pakrid]
# 23    isolated-left     itemchange      [makkot, haagle, pakrid]
# 24  isolated-center  transposition      [rakken, pakrid, dingep]
# 25  isolated-center  transposition  [fisslin, haagle, goorshell]
# 26  isolated-center  transposition     [sumbark, rakken, dingep]
# 27  isolated-center  transposition    [makkot, fisslin, sumbark]
# 28  isolated-center  transposition     [haagle, fisslin, barget]
# 29  isolated-center  transposition     [bimdah, haagle, fisslin]
# 30  isolated-center     itemchange      [rakken, makkot, haagle]
# 31  isolated-center     itemchange     [barget, fisslin, pakrid]
# 32  isolated-center     itemchange      [makkot, haagle, pakrid]
# 33  isolated-center     itemchange      [haagle, pakrid, barget]
# 34  isolated-center     itemchange     [rakken, fisslin, haagle]
# 35  isolated-center     itemchange  [bimdah, sumbark, goorshell]
# 36   isolated-right  transposition     [dingep, sumbark, rakken]
# 37   isolated-right  transposition      [dingep, rakken, pakrid]
# 38   isolated-right  transposition     [bimdah, haagle, fisslin]
# 39   isolated-right  transposition     [rakken, fisslin, makkot]
# 40   isolated-right  transposition      [pakrid, rakken, makkot]
# 41   isolated-right  transposition    [makkot, sumbark, fisslin]
# 42   isolated-right     itemchange  [goorshell, barget, sumbark]
# 43   isolated-right     itemchange      [makkot, barget, haagle]
# 44   isolated-right     itemchange   [rakken, pakrid, goorshell]
# 45   isolated-right     itemchange    [sumbark, fisslin, rakken]
# 46   isolated-right     itemchange  [fisslin, goorshell, rakken]
# 47   isolated-right     itemchange      [bimdah, haagle, makkot]

# %% [markdown]
# ### Archived Logic for Test

# %%
# Randomly select 12 items from selected_permutations
test_selected_permutations = random.sample(selected_permutations, 12)

# Identify the remaining items for case markers
remaining_items = list(set(syllabus_pool) - set(selected_items))

# Randomly select 12 items to be used as case markers for the test_df
test_casemarker_items = random.sample(remaining_items, 3)

# Create the initial DataFrame for the test_df
test_df = pd.DataFrame({
    'trial': range(1, 13),
    'item1': [p[0] for p in test_selected_permutations],
    'item2': [p[1] for p in test_selected_permutations],
    'item3': [p[2] for p in test_selected_permutations],
    'casemarker1': test_casemarker_items[0],  
    'casemarker2': test_casemarker_items[1],  
    'casemarker3': test_casemarker_items[2],
})

# Create a concatenated column for items and case markers in test_df
test_df['target'] = test_df['item1'] + " " + test_df['casemarker1'] + " " + test_df['item2'] + " " + test_df['casemarker2'] + " " + test_df['item3'] + " " + test_df['casemarker3']

test_df
# Out:
#     trial      item1      item2      item3 casemarker1 casemarker2  \
# 0       1     barget    fisslin     makkot      chelad     limeber
# 1       2     pakrid     haagle     bimdah      chelad     limeber
# 2       3     barget  goorshell     makkot      chelad     limeber
# 3       4    fisslin     haagle     bimdah      chelad     limeber
# 4       5     barget    fisslin     haagle      chelad     limeber
# 5       6  goorshell     makkot    sumbark      chelad     limeber
# 6       7     rakken     dingep     pakrid      chelad     limeber
# 7       8    sumbark    fisslin     makkot      chelad     limeber
# 8       9     bimdah     haagle  goorshell      chelad     limeber
# 9      10     barget     dingep    sumbark      chelad     limeber
# 10     11     rakken     makkot     pakrid      chelad     limeber
# 11     12     rakken     dingep    sumbark      chelad     limeber
#
#    casemarker3                                          target
# 0       jeelow     barget chelad fisslin limeber makkot jeelow
# 1       jeelow      pakrid chelad haagle limeber bimdah jeelow
# 2       jeelow   barget chelad goorshell limeber makkot jeelow
# 3       jeelow     fisslin chelad haagle limeber bimdah jeelow
# 4       jeelow     barget chelad fisslin limeber haagle jeelow
# 5       jeelow  goorshell chelad makkot limeber sumbark jeelow
# 6       jeelow      rakken chelad dingep limeber pakrid jeelow
# 7       jeelow    sumbark chelad fisslin limeber makkot jeelow
# 8       jeelow   bimdah chelad haagle limeber goorshell jeelow
# 9       jeelow     barget chelad dingep limeber sumbark jeelow
# 10      jeelow      rakken chelad makkot limeber pakrid jeelow
# 11      jeelow     rakken chelad dingep limeber sumbark jeelow
